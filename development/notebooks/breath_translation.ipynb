# %% [markdown]
# ### Оцифровка дыхания
# #### В данном ноутбуке реализуется оцифровка дыхания (из волны или спектрограммы в буквы)

# %%
import warnings
import time
import os
import sys

warnings.simplefilter(action='ignore')

import pandas as pd
from matplotlib import pyplot as plt
import numpy as np
import librosa
import sklearn
from scipy.spatial.distance import euclidean
from scipy.signal import correlate
import hashlib

# %% [markdown]
# Сравнение волн

# %%
def load_audio(file_path):
    # Load the audio file
    signal, sr = librosa.load(file_path, sr=None)
    return signal, sr

def compare_waveforms(signal1, signal2):
    # Normalize signals
    signal1 = signal1 / np.max(np.abs(signal1))
    signal2 = signal2 / np.max(np.abs(signal2))
    # Compute cross-correlation
    correlation = correlate(signal1, signal2, mode='full')
    max_corr = np.max(correlation)
    return max_corr

def compare_mfcc(file1, file2):
    # Extract MFCC features
    signal1, sr1 = load_audio(file1)
    signal2, sr2 = load_audio(file2)
    mfcc1 = librosa.feature.mfcc(y=signal1, sr=sr1, n_mfcc=13)
    mfcc2 = librosa.feature.mfcc(y=signal2, sr=sr2, n_mfcc=13)

    # Use Dynamic Time Warping (DTW) to measure similarity
    distance, _, _, _ = dtw(mfcc1.T, mfcc2.T, dist_method=euclidean)
    return distance

# %% [markdown]
# Сравнение спектрограмм и хэширование

# %%
def compute_spectrogram_hash(audio_file):
    # Load the audio file with its original sampling rate.
    y, sr = librosa.load(audio_file, sr=None)
    
    # Compute the short-time Fourier transform (STFT) to get the spectrogram.
    # The magnitude (absolute value) is used to represent the intensity.
    S = np.abs(librosa.stft(y))
    
    # Normalize the spectrogram to the range [0, 1]
    S_norm = (S - S.min()) / (S.max() - S.min())
    
    # Quantize the normalized spectrogram to 8-bit integers (0-255)
    S_quantized = (S_norm * 255).astype(np.uint8)
    
    # Convert the quantized spectrogram into bytes
    spectrogram_bytes = S_quantized.tobytes()
    
    # Create a SHA256 hash of the spectrogram bytes
    hash_obj = hashlib.sha256(spectrogram_bytes)
    hash_value = hash_obj.hexdigest()
    
    return hash_value

# %%
def hex_to_bin(hex_string):
    """
    Convert a hexadecimal string into a binary string,
    ensuring that leading zeros are preserved.
    """
    num_bits = len(hex_string) * 4  # each hex digit is 4 bits
    return bin(int(hex_string, 16))[2:].zfill(num_bits)

def compute_similarity(hash1, hash2):
    """
    Compute the similarity between two hex hash strings by comparing
    their binary representations. Returns a percentage of identical bits.
    """
    # Convert hex strings to binary strings
    bin1 = hex_to_bin(hash1)
    bin2 = hex_to_bin(hash2)

    if len(bin1) != len(bin2):
        raise ValueError("Hashes must be of the same length for comparison.")

    # Calculate the number of identical bits
    identical_bits = sum(b1 == b2 for b1, b2 in zip(bin1, bin2))
    total_bits = len(bin1)
    
    # Compute similarity percentage
    similarity_percentage = (identical_bits / total_bits) * 100
    return similarity_percentage

# %% [markdown]
# Audio fingerprinting

# %%
from scipy.ndimage import maximum_filter
from math import exp, sqrt


def compute_spectrogram(audio_file):
    """
    Load an audio file and compute its STFT magnitude spectrogram.
    The spectrogram is converted to dB scale.
    """
    y, sr = librosa.load(audio_file, sr=None)
    S = np.abs(librosa.stft(y, n_fft=2048, hop_length=512))
    S_db = librosa.amplitude_to_db(S, ref=np.max)
    return S_db, sr

def extract_peaks(S_db, amp_min=-40, neighborhood_size=(20, 20)):
    """
    Identify local spectral peaks in the dB-scaled spectrogram.
    Only peaks above the amp_min threshold are retained.
    """
    local_max = maximum_filter(S_db, size=neighborhood_size) == S_db
    detected_peaks = np.where(local_max & (S_db >= amp_min))
    peaks = list(zip(detected_peaks[0], detected_peaks[1]))
    return peaks

def generate_features_from_peaks(peaks, fan_value=5, delta_time_max=10):
    """
    Instead of generating discrete hash strings, generate numerical fingerprint
    features. Each feature is a tuple: (freq1, freq2, time_delta)
    where freq1 and freq2 are frequency bins of paired peaks and time_delta is their time difference.
    """
    peaks.sort(key=lambda x: x[1])  # sort by time
    features = []
    num_peaks = len(peaks)
    
    for i in range(num_peaks):
        freq1, time1 = peaks[i]
        for j in range(1, fan_value + 1):
            if i + j < num_peaks:
                freq2, time2 = peaks[i + j]
                time_delta = time2 - time1
                if 0 < time_delta <= delta_time_max:
                    features.append((freq1, freq2, time_delta))
    return features

def extract_audio_fingerprint(audio_file):
    """
    Extract continuous fingerprint features from an audio file.
    Returns a list of tuples (freq1, freq2, time_delta)
    """
    S_db, sr = compute_spectrogram(audio_file)
    peaks = extract_peaks(S_db, amp_min=-40, neighborhood_size=(20, 20))
    features = generate_features_from_peaks(peaks, fan_value=5, delta_time_max=10)
    return features

def feature_distance(feat1, feat2):
    """
    Compute Euclidean distance between two fingerprint features.
    Each feature is a tuple (freq1, freq2, time_delta).
    """
    return sqrt(sum((a - b) ** 2 for a, b in zip(feat1, feat2)))

def gaussian_similarity(distance, sigma=10.0):
    """
    Convert a distance to a similarity score using a Gaussian kernel.
    The score is in the range (0, 1], where 0 means no similarity and 1 means perfect match.
    """
    return exp(- (distance ** 2) / (2 * sigma ** 2))

def compute_continuous_similarity(fp_features1, fp_features2, sigma=10.0):
    """
    Compute a continuous similarity score between two sets of fingerprint features.
    
    For each feature in the first fingerprint, find the closest feature in the second fingerprint
    (using Euclidean distance), convert that distance into a similarity score via a Gaussian kernel,
    and average these scores. Repeat symmetrically and then average both directions.
    """
    if not fp_features1 or not fp_features2:
        return 0.0

    def avg_similarity(features_A, features_B):
        total_sim = 0.0
        for feat_A in features_A:
            # Find the minimum distance to any feature in features_B
            min_dist = min(feature_distance(feat_A, feat_B) for feat_B in features_B)
            total_sim += gaussian_similarity(min_dist, sigma=sigma)
        return total_sim / len(features_A)
    
    sim1 = avg_similarity(fp_features1, fp_features2)
    sim2 = avg_similarity(fp_features2, fp_features1)
    # Average the two directional similarities
    return (sim1 + sim2) / 2

# %%
data_path = '../letters_source_files/'

# %%
# %matplotlib inline

x , sr = load_audio(data_path + 'т.wav')
X = librosa.stft(x)
Xdb = librosa.amplitude_to_db(abs(X))
plt.figure(figsize=(15, 5))
librosa.display.specshow(Xdb, sr=sr, x_axis='time', y_axis='hz', cmap='magma')
plt.colorbar()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 3
#       1 get_ipython().run_line_magic('matplotlib', 'inline')
# ----> 3 x , sr = load_audio(data_path + 'т.wav')
#       4 X = librosa.stft(x)
#       5 Xdb = librosa.amplitude_to_db(abs(X))
#
# NameError: name 'data_path' is not defined

# %%
file1 = "modified_letters/х.wav"
file2 = "modified_letters/х.wav"

# Load audio
signal1, sr1 = load_audio(file1)
signal2, sr2 = load_audio(file2)

# Waveform similarity
waveform_similarity = compare_waveforms(signal1, signal2)
print(f"Waveform Similarity (Max Correlation): {waveform_similarity}")

# MFCC similarity
# mfcc_distance = compare_mfcc(file1, file2)
# print(f"MFCC Distance: {mfcc_distance}")
# Out:
# ---------------------------------------------------------------------------
# LibsndfileError                           Traceback (most recent call last)
# File ~/project/breathing_analysis/.venv/lib/python3.11/site-packages/librosa/core/audio.py:176, in load(path, sr, mono, offset, duration, dtype, res_type)
#     175 try:
# --> 176     y, sr_native = __soundfile_load(path, offset, duration, dtype)
#     178 except sf.SoundFileRuntimeError as exc:
#     179     # If soundfile failed, try audioread instead
#
# File ~/project/breathing_analysis/.venv/lib/python3.11/site-packages/librosa/core/audio.py:209, in __soundfile_load(path, offset, duration, dtype)
#     207 else:
#     208     # Otherwise, create the soundfile object
# --> 209     context = sf.SoundFile(path)
#     211 with context as sf_desc:
#
# File ~/project/breathing_analysis/.venv/lib/python3.11/site-packages/soundfile.py:690, in SoundFile.__init__(self, file, mode, samplerate, channels, subtype, endian, format, closefd, compression_level, bitrate_mode)
#     688 self._info = _create_info_struct(file, mode, samplerate, channels,
#     689                                  format, subtype, endian)
# --> 690 self._file = self._open(file, mode_int, closefd)
#     691 if set(mode).issuperset('r+') and self.seekable():
#     692     # Move write position to 0 (like in Python file objects)
#
# File ~/project/breathing_analysis/.venv/lib/python3.11/site-packages/soundfile.py:1265, in SoundFile._open(self, file, mode_int, closefd)
#    1264     err = _snd.sf_error(file_ptr)
# -> 1265     raise LibsndfileError(err, prefix="Error opening {0!r}: ".format(self.name))
#    1266 if mode_int == _snd.SFM_WRITE:
#    1267     # Due to a bug in libsndfile version <= 1.0.25, frames != 0
#    1268     # when opening a named pipe in SFM_WRITE mode.
#    1269     # See http://github.com/erikd/libsndfile/issues/77.
#
# LibsndfileError: Error opening 'modified_letters/х.wav': System error.
#
# During handling of the above exception, another exception occurred:
#
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[8], line 5
#       2 file2 = "modified_letters/х.wav"
#       4 # Load audio
# ----> 5 signal1, sr1 = load_audio(file1)
#       6 signal2, sr2 = load_audio(file2)
#       8 # Waveform similarity
#
# Cell In[2], line 3, in load_audio(file_path)
#       1 def load_audio(file_path):
#       2     # Load the audio file
# ----> 3     signal, sr = librosa.load(file_path, sr=None)
#       4     return signal, sr
#
# File ~/project/breathing_analysis/.venv/lib/python3.11/site-packages/librosa/core/audio.py:184, in load(path, sr, mono, offset, duration, dtype, res_type)
#     180 if isinstance(path, (str, pathlib.PurePath)):
#     181     warnings.warn(
#     182         "PySoundFile failed. Trying audioread instead.", stacklevel=2
#     183     )
# --> 184     y, sr_native = __audioread_load(path, offset, duration, dtype)
#     185 else:
#     186     raise exc
#
# File ~/project/breathing_analysis/.venv/lib/python3.11/site-packages/decorator.py:232, in decorate.<locals>.fun(*args, **kw)
#     230 if not kwsyntax:
#     231     args, kw = fix(args, kw, sig)
# --> 232 return caller(func, *(extras + args), **kw)
#
# File ~/project/breathing_analysis/.venv/lib/python3.11/site-packages/librosa/util/decorators.py:59, in deprecated.<locals>.__wrapper(func, *args, **kwargs)
#      50 """Warn the user, and then proceed."""
#      51 warnings.warn(
#      52     "{:s}.{:s}\n\tDeprecated as of librosa version {:s}."
#      53     "\n\tIt will be removed in librosa version {:s}.".format(
#    (...)
#      57     stacklevel=3,  # Would be 2, but the decorator adds a level
#      58 )
# ---> 59 return func(*args, **kwargs)
#
# File ~/project/breathing_analysis/.venv/lib/python3.11/site-packages/librosa/core/audio.py:240, in __audioread_load(path, offset, duration, dtype)
#     237     reader = path
#     238 else:
#     239     # If the input was not an audioread object, try to open it
# --> 240     reader = audioread.audio_open(path)
#     242 with reader as input_file:
#     243     sr_native = input_file.samplerate
#
# File ~/project/breathing_analysis/.venv/lib/python3.11/site-packages/audioread/__init__.py:127, in audio_open(path, backends)
#     125 for BackendClass in backends:
#     126     try:
# --> 127         return BackendClass(path)
#     128     except DecodeError:
#     129         pass
#
# File ~/project/breathing_analysis/.venv/lib/python3.11/site-packages/audioread/rawread.py:59, in RawAudioFile.__init__(self, filename)
#      58 def __init__(self, filename):
# ---> 59     self._fh = open(filename, 'rb')
#      61     try:
#      62         self._file = aifc.open(self._fh)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'modified_letters/х.wav'

# %%
from pydub import AudioSegment
import glob
import random

work_directory = "../web_recordings/Sitting/audio/"
breath_files = glob.glob(work_directory + "*.wav")
letters = glob.glob("letters_source_files/*.wav")

for b in random.sample(breath_files, 2):
    breath_audio, sr = load_audio(b)
    duration = librosa.get_duration(y=breath_audio, sr=sr) * 1000
    breath = AudioSegment.from_wav(b)

    print(b + ":", end=' ')
    for x in range(0, int(duration), 200):
        breath_fragment = breath[x:x+200]
        temp_output = "temp_fragment.wav"
        breath_fragment.export(temp_output, format='wav')

        # comparing
        best_similarity = {}
        breath_fragment_for_comparing, sr1 = load_audio(temp_output)
        print (breath_fragment_for_comparing)
        for letter in letters:
            # print(letter)
            current_letter, sr2 = load_audio(letter)
            waveform_similarity = compare_waveforms(breath_fragment_for_comparing, current_letter)
            best_similarity[letter[15]] = float(waveform_similarity)
        print(max(best_similarity, key=best_similarity.get), end='')
    print("")

os.remove(temp_output)
# Out:
# ../web_recordings/Sitting/audio/Sitting_inhale_3.wav: [0.00033569 0.00018311 0.         ... 0.00073242 0.0007019  0.00061035]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[12], line 29
#      27             waveform_similarity = compare_waveforms(breath_fragment_for_comparing, current_letter)
#      28             best_similarity[letter[15]] = float(waveform_similarity)
# ---> 29         print(max(best_similarity, key=best_similarity.get), end='')
#      30     print("")
#      32 os.remove(temp_output)
#
# ValueError: max() arg is an empty sequence

# %%
import string


data_path = "web_recordings/z/z_inhale_1.wav"
x , sr = librosa.load(data_path)

plt.figure(figsize=(20, 5))
translate = 'ииункощуи'

librosa.display.waveshow(x, sr=sr)
plt.xlabel("Time (s)")
plt.ylabel("Amplitude")
duration = librosa.get_duration(y=x, sr=sr)
time_points = np.arange(0.1, duration, 0.2)

letters = list(translate)

# Add letters under the x-axis
for t, letter in zip(time_points, letters):
    plt.text(t, -0.18, letter, ha='center', va='center', fontsize=10, transform=plt.gca().transData)
    plt.axvline(x=t-0.1, color='gray', linestyle='--', linewidth=1)  # Vertical line at time 't-0.1'
    plt.axvline(x=t+0.1, color='gray', linestyle='--', linewidth=1)  # Vertical line at time 't+0.1'


# Adjust the limits and show the plot
plt.ylim(-0.2, 0.2)  # Adjust the y-axis to avoid overlap
plt.show()

# %% [markdown]
# Хэширование и сравнение

# %%
file1 = data_path + "х.wav"
file2 = data_path + "ф.wav"

# Load audio
file1_hash = compute_spectrogram_hash(file1)
file2_hash = compute_spectrogram_hash(file2)

# Spectrogram similarity
hash_similarity = compute_similarity(file1_hash, file2_hash)
print(f"Hash Similarity: {hash_similarity}")
# Out:
# Hash Similarity: 51.953125

# %%
import glob
import random
from pydub import AudioSegment

work_directory = "../web_recordings/Sitting/audio/"
breath_files = glob.glob(work_directory + "*.wav")
letters = glob.glob("../letters_source_files/*.wav")

for b in random.sample(breath_files, 10):
    breath_audio, sr = load_audio(b)
    duration = librosa.get_duration(y=breath_audio, sr=sr) * 1000
    breath = AudioSegment.from_wav(b)

    print(b + ":", end=' ')
    for x in range(0, int(duration), 200):
        breath_fragment = breath[x:x+200]
        temp_output = "temp_fragment.wav"
        breath_fragment.export(temp_output, format='wav')

        # comparing
        best_similarity = {}
        breath_hash = compute_spectrogram_hash(temp_output)
        for letter in letters:
            # print(letter)
            letter_hash = compute_spectrogram_hash(letter)
            hash_similarity = compute_similarity(breath_hash, letter_hash)
            best_similarity[letter[24]] = float(hash_similarity)
        print(max(best_similarity, key=best_similarity.get), end='')
    print("")

os.remove(temp_output)
# Out:
# ../web_recordings/Sitting/audio/Sitting_exhale_7.wav: ыпсцудзмогпзрм
# ../web_recordings/Sitting/audio/Sitting_inhale_10.wav: мупвссыугрглвзр
# ../web_recordings/Sitting/audio/Sitting_inhale_6.wav: щсфчааувпзкву
# ../web_recordings/Sitting/audio/Sitting_inhale_4.wav: влфзчлкшунчдоф
# ../web_recordings/Sitting/audio/Sitting_inhale_9.wav: фгмжбчмгонза
# ../web_recordings/Sitting/audio/Sitting_exhale_10.wav: гчкбтсзртодсы
# ../web_recordings/Sitting/audio/Sitting_exhale_6.wav: ипмоиргжчсрдзза
# ../web_recordings/Sitting/audio/Sitting_inhale_5.wav: кафзмбамсрибц
# ../web_recordings/Sitting/audio/Sitting_exhale_8.wav: учжжитзмвывс
# ../web_recordings/Sitting/audio/Sitting_inhale_8.wav: шжнуцомцуычн

# %% [markdown]
# Audio fingerprinting

# %%
file1 = data_path + "а.wav"
file2 = data_path + "п.wav"

# Load audio
file1_fingerprint = extract_audio_fingerprint(file1)
file2_fingerprint = extract_audio_fingerprint(file2)

# Fingerprint similarity
fingerprint_similarity = compute_continuous_similarity(file1_fingerprint, file2_fingerprint)
print(f"Fingerprint Similarity: {fingerprint_similarity}")
# Out:
# Fingerprint Similarity: 0.0

# %%
import glob
import random
from pydub import AudioSegment

work_directory = "../web_recordings/Sitting/audio/"
breath_files = glob.glob(work_directory + "*.wav")
letters = glob.glob("../letters_source_files/*.wav")

for b in random.sample(breath_files, 10):
    breath_audio, sr = load_audio(b)
    duration = librosa.get_duration(y=breath_audio, sr=sr) * 1000
    breath = AudioSegment.from_wav(b)

    print(b + ":", end=' ')
    for x in range(0, int(duration), 200):
        breath_fragment = breath[x:x+200]
        temp_output = "temp_fragment.wav"
        breath_fragment.export(temp_output, format='wav')

        # comparing
        best_similarity = {}
        breath_hash = extract_audio_fingerprint(temp_output)
        for letter in letters:
            # print(letter)
            letter_hash = extract_audio_fingerprint(letter)
            print(letter_hash)
            hash_similarity = compute_continuous_similarity(breath_hash, letter_hash)
            best_similarity[letter[24]] = float(hash_similarity)
        print(max(best_similarity, key=best_similarity.get), end='')
    print("")

os.remove(temp_output)
# Out:
# ../web_recordings/Sitting/audio/Sitting_exhale_6.wav: [(np.int64(378), np.int64(160), np.int64(1)), (np.int64(378), np.int64(322), np.int64(1)), (np.int64(378), np.int64(334), np.int64(1)), (np.int64(406), np.int64(160), np.int64(1)), (np.int64(406), np.int64(322), np.int64(1)), (np.int64(406), np.int64(334), np.int64(1)), (np.int64(406), np.int64(175), np.int64(2)), (np.int64(445), np.int64(160), np.int64(1)), (np.int64(445), np.int64(322), np.int64(1)), (np.int64(445), np.int64(334), np.int64(1)), (np.int64(445), np.int64(175), np.int64(2)), (np.int64(445), np.int64(246), np.int64(2)), (np.int64(160), np.int64(175), np.int64(1)), (np.int64(160), np.int64(246), np.int64(1)), (np.int64(160), np.int64(0), np.int64(2)), (np.int64(322), np.int64(175), np.int64(1)), (np.int64(322), np.int64(246), np.int64(1)), (np.int64(322), np.int64(0), np.int64(2)), (np.int64(322), np.int64(41), np.int64(2)), (np.int64(334), np.int64(175), np.int64(1)), (np.int64(334), np.int64(246), np.int64(1)), (np.int64(334), np.int64(0), np.int64(2)), (np.int64(334), np.int64(41), np.int64(2)), (np.int64(334), np.int64(351), np.int64(2)), (np.int64(175), np.int64(0), np.int64(1)), (np.int64(175), np.int64(41), np.int64(1)), (np.int64(175), np.int64(351), np.int64(1)), (np.int64(175), np.int64(207), np.int64(3)), (np.int64(246), np.int64(0), np.int64(1)), (np.int64(246), np.int64(41), np.int64(1)), (np.int64(246), np.int64(351), np.int64(1)), (np.int64(246), np.int64(207), np.int64(3)), (np.int64(246), np.int64(266), np.int64(3)), (np.int64(0), np.int64(207), np.int64(2)), (np.int64(0), np.int64(266), np.int64(2)), (np.int64(0), np.int64(220), np.int64(3)), (np.int64(41), np.int64(207), np.int64(2)), (np.int64(41), np.int64(266), np.int64(2)), (np.int64(41), np.int64(220), np.int64(3)), (np.int64(41), np.int64(308), np.int64(3)), (np.int64(351), np.int64(207), np.int64(2)), (np.int64(351), np.int64(266), np.int64(2)), (np.int64(351), np.int64(220), np.int64(3)), (np.int64(351), np.int64(308), np.int64(3)), (np.int64(351), np.int64(286), np.int64(4)), (np.int64(207), np.int64(220), np.int64(1)), (np.int64(207), np.int64(308), np.int64(1)), (np.int64(207), np.int64(286), np.int64(2)), (np.int64(266), np.int64(220), np.int64(1)), (np.int64(266), np.int64(308), np.int64(1)), (np.int64(266), np.int64(286), np.int64(2)), (np.int64(220), np.int64(286), np.int64(1)), (np.int64(308), np.int64(286), np.int64(1))]
# [(np.int64(0), np.int64(18), np.int64(7))]
# [(np.int64(56), np.int64(0), np.int64(3))]
# [(np.int64(6), np.int64(46), np.int64(1))]
# [(np.int64(0), np.int64(205), np.int64(5)), (np.int64(0), np.int64(240), np.int64(7)), (np.int64(0), np.int64(348), np.int64(7)), (np.int64(0), np.int64(36), np.int64(8)), (np.int64(158), np.int64(205), np.int64(5)), (np.int64(158), np.int64(240), np.int64(7)), (np.int64(158), np.int64(348), np.int64(7)), (np.int64(158), np.int64(36), np.int64(8)), (np.int64(158), np.int64(192), np.int64(8)), (np.int64(205), np.int64(240), np.int64(2)), (np.int64(205), np.int64(348), np.int64(2)), (np.int64(205), np.int64(36), np.int64(3)), (np.int64(205), np.int64(192), np.int64(3)), (np.int64(205), np.int64(280), np.int64(3)), (np.int64(240), np.int64(36), np.int64(1)), (np.int64(240), np.int64(192), np.int64(1)), (np.int64(240), np.int64(280), np.int64(1)), (np.int64(240), np.int64(47), np.int64(3)), (np.int64(348), np.int64(36), np.int64(1)), (np.int64(348), np.int64(192), np.int64(1)), (np.int64(348), np.int64(280), np.int64(1)), (np.int64(348), np.int64(47), np.int64(3)), (np.int64(348), np.int64(314), np.int64(3)), (np.int64(36), np.int64(47), np.int64(2)), (np.int64(36), np.int64(314), np.int64(2)), (np.int64(36), np.int64(143), np.int64(3)), (np.int64(192), np.int64(47), np.int64(2)), (np.int64(192), np.int64(314), np.int64(2)), (np.int64(192), np.int64(143), np.int64(3)), (np.int64(192), np.int64(0), np.int64(4)), (np.int64(280), np.int64(47), np.int64(2)), (np.int64(280), np.int64(314), np.int64(2)), (np.int64(280), np.int64(143), np.int64(3)), (np.int64(280), np.int64(0), np.int64(4)), (np.int64(280), np.int64(177), np.int64(4)), (np.int64(47), np.int64(143), np.int64(1)), (np.int64(47), np.int64(0), np.int64(2)), (np.int64(47), np.int64(177), np.int64(2)), (np.int64(47), np.int64(253), np.int64(2)), (np.int64(314), np.int64(143), np.int64(1)), (np.int64(314), np.int64(0), np.int64(2)), (np.int64(314), np.int64(177), np.int64(2)), (np.int64(314), np.int64(253), np.int64(2)), (np.int64(314), np.int64(225), np.int64(4)), (np.int64(143), np.int64(0), np.int64(1)), (np.int64(143), np.int64(177), np.int64(1)), (np.int64(143), np.int64(253), np.int64(1)), (np.int64(143), np.int64(225), np.int64(3)), (np.int64(143), np.int64(21), np.int64(5)), (np.int64(0), np.int64(225), np.int64(2)), (np.int64(0), np.int64(21), np.int64(4)), (np.int64(0), np.int64(112), np.int64(4)), (np.int64(177), np.int64(225), np.int64(2)), (np.int64(177), np.int64(21), np.int64(4)), (np.int64(177), np.int64(112), np.int64(4)), (np.int64(177), np.int64(80), np.int64(5)), (np.int64(253), np.int64(225), np.int64(2)), (np.int64(253), np.int64(21), np.int64(4)), (np.int64(253), np.int64(112), np.int64(4)), (np.int64(253), np.int64(80), np.int64(5)), (np.int64(225), np.int64(21), np.int64(2)), (np.int64(225), np.int64(112), np.int64(2)), (np.int64(225), np.int64(80), np.int64(3)), (np.int64(21), np.int64(80), np.int64(1)), (np.int64(112), np.int64(80), np.int64(1))]
# []
# [(np.int64(4), np.int64(21), np.int64(6))]
# [(np.int64(4), np.int64(40), np.int64(3))]
# [(np.int64(46), np.int64(5), np.int64(2))]
# []
# [(np.int64(158), np.int64(29), np.int64(2)), (np.int64(158), np.int64(0), np.int64(9)), (np.int64(29), np.int64(0), np.int64(7))]
# [(np.int64(3), np.int64(38), np.int64(1)), (np.int64(3), np.int64(88), np.int64(1)), (np.int64(25), np.int64(38), np.int64(1)), (np.int64(25), np.int64(88), np.int64(1))]
# [(np.int64(4), np.int64(19), np.int64(5)), (np.int64(4), np.int64(38), np.int64(5))]
# [(np.int64(5), np.int64(22), np.int64(4))]
# [(np.int64(37), np.int64(5), np.int64(9)), (np.int64(5), np.int64(36), np.int64(3)), (np.int64(5), np.int64(51), np.int64(3))]
# []
# []
# [(np.int64(0), np.int64(41), np.int64(5)), (np.int64(0), np.int64(196), np.int64(9)), (np.int64(41), np.int64(196), np.int64(4))]
# [(np.int64(40), np.int64(4), np.int64(3))]
# []
# [(np.int64(1), np.int64(89), np.int64(5)), (np.int64(1), np.int64(44), np.int64(7)), (np.int64(1), np.int64(60), np.int64(9)), (np.int64(1), np.int64(77), np.int64(9)), (np.int64(1), np.int64(142), np.int64(9)), (np.int64(89), np.int64(44), np.int64(2)), (np.int64(89), np.int64(60), np.int64(4)), (np.int64(89), np.int64(77), np.int64(4)), (np.int64(89), np.int64(142), np.int64(4)), (np.int64(89), np.int64(158), np.int64(4)), (np.int64(44), np.int64(60), np.int64(2)), (np.int64(44), np.int64(77), np.int64(2)), (np.int64(44), np.int64(142), np.int64(2)), (np.int64(44), np.int64(158), np.int64(2)), (np.int64(44), np.int64(205), np.int64(2)), (np.int64(142), np.int64(176), np.int64(1)), (np.int64(158), np.int64(176), np.int64(1)), (np.int64(158), np.int64(22), np.int64(2)), (np.int64(205), np.int64(176), np.int64(1)), (np.int64(205), np.int64(22), np.int64(2)), (np.int64(205), np.int64(131), np.int64(2)), (np.int64(265), np.int64(176), np.int64(1)), (np.int64(265), np.int64(22), np.int64(2)), (np.int64(265), np.int64(131), np.int64(2)), (np.int64(265), np.int64(223), np.int64(2)), (np.int64(351), np.int64(176), np.int64(1)), (np.int64(351), np.int64(22), np.int64(2)), (np.int64(351), np.int64(131), np.int64(2)), (np.int64(351), np.int64(223), np.int64(2)), (np.int64(351), np.int64(246), np.int64(2)), (np.int64(176), np.int64(22), np.int64(1)), (np.int64(176), np.int64(131), np.int64(1)), (np.int64(176), np.int64(223), np.int64(1)), (np.int64(176), np.int64(246), np.int64(1))]
# [(np.int64(0), np.int64(159), np.int64(4)), (np.int64(0), np.int64(146), np.int64(6)), (np.int64(0), np.int64(247), np.int64(6)), (np.int64(0), np.int64(125), np.int64(8)), (np.int64(0), np.int64(195), np.int64(8)), (np.int64(159), np.int64(146), np.int64(2)), (np.int64(159), np.int64(247), np.int64(2)), (np.int64(159), np.int64(125), np.int64(4)), (np.int64(159), np.int64(195), np.int64(4)), (np.int64(159), np.int64(314), np.int64(4)), (np.int64(146), np.int64(125), np.int64(2)), (np.int64(146), np.int64(195), np.int64(2)), (np.int64(146), np.int64(314), np.int64(2)), (np.int64(146), np.int64(46), np.int64(3)), (np.int64(247), np.int64(125), np.int64(2)), (np.int64(247), np.int64(195), np.int64(2)), (np.int64(247), np.int64(314), np.int64(2)), (np.int64(247), np.int64(46), np.int64(3)), (np.int64(247), np.int64(271), np.int64(3)), (np.int64(125), np.int64(46), np.int64(1)), (np.int64(125), np.int64(271), np.int64(1)), (np.int64(125), np.int64(299), np.int64(1)), (np.int64(195), np.int64(46), np.int64(1)), (np.int64(195), np.int64(271), np.int64(1)), (np.int64(195), np.int64(299), np.int64(1)), (np.int64(195), np.int64(381), np.int64(1)), (np.int64(314), np.int64(46), np.int64(1)), (np.int64(314), np.int64(271), np.int64(1)), (np.int64(314), np.int64(299), np.int64(1)), (np.int64(314), np.int64(381), np.int64(1)), (np.int64(314), np.int64(80), np.int64(2)), (np.int64(46), np.int64(80), np.int64(1)), (np.int64(46), np.int64(212), np.int64(1)), (np.int64(271), np.int64(80), np.int64(1)), (np.int64(271), np.int64(212), np.int64(1)), (np.int64(271), np.int64(112), np.int64(3)), (np.int64(299), np.int64(80), np.int64(1)), (np.int64(299), np.int64(212), np.int64(1)), (np.int64(299), np.int64(112), np.int64(3)), (np.int64(299), np.int64(19), np.int64(5)), (np.int64(381), np.int64(80), np.int64(1)), (np.int64(381), np.int64(212), np.int64(1)), (np.int64(381), np.int64(112), np.int64(3)), (np.int64(381), np.int64(19), np.int64(5)), (np.int64(381), np.int64(0), np.int64(7)), (np.int64(80), np.int64(112), np.int64(2)), (np.int64(80), np.int64(19), np.int64(4)), (np.int64(80), np.int64(0), np.int64(6)), (np.int64(212), np.int64(112), np.int64(2)), (np.int64(212), np.int64(19), np.int64(4)), (np.int64(212), np.int64(0), np.int64(6)), (np.int64(112), np.int64(19), np.int64(2)), (np.int64(112), np.int64(0), np.int64(4)), (np.int64(19), np.int64(0), np.int64(2))]
# []
# ч[(np.int64(378), np.int64(160), np.int64(1)), (np.int64(378), np.int64(322), np.int64(1)), (np.int64(378), np.int64(334), np.int64(1)), (np.int64(406), np.int64(160), np.int64(1)), (np.int64(406), np.int64(322), np.int64(1)), (np.int64(406), np.int64(334), np.int64(1)), (np.int64(406), np.int64(175), np.int64(2)), (np.int64(445), np.int64(160), np.int64(1)), (np.int64(445), np.int64(322), np.int64(1)), (np.int64(445), np.int64(334), np.int64(1)), (np.int64(445), np.int64(175), np.int64(2)), (np.int64(445), np.int64(246), np.int64(2)), (np.int64(160), np.int64(175), np.int64(1)), (np.int64(160), np.int64(246), np.int64(1)), (np.int64(160), np.int64(0), np.int64(2)), (np.int64(322), np.int64(175), np.int64(1)), (np.int64(322), np.int64(246), np.int64(1)), (np.int64(322), np.int64(0), np.int64(2)), (np.int64(322), np.int64(41), np.int64(2)), (np.int64(334), np.int64(175), np.int64(1)), (np.int64(334), np.int64(246), np.int64(1)), (np.int64(334), np.int64(0), np.int64(2)), (np.int64(334), np.int64(41), np.int64(2)), (np.int64(334), np.int64(351), np.int64(2)), (np.int64(175), np.int64(0), np.int64(1)), (np.int64(175), np.int64(41), np.int64(1)), (np.int64(175), np.int64(351), np.int64(1)), (np.int64(175), np.int64(207), np.int64(3)), (np.int64(246), np.int64(0), np.int64(1)), (np.int64(246), np.int64(41), np.int64(1)), (np.int64(246), np.int64(351), np.int64(1)), (np.int64(246), np.int64(207), np.int64(3)), (np.int64(246), np.int64(266), np.int64(3)), (np.int64(0), np.int64(207), np.int64(2)), (np.int64(0), np.int64(266), np.int64(2)), (np.int64(0), np.int64(220), np.int64(3)), (np.int64(41), np.int64(207), np.int64(2)), (np.int64(41), np.int64(266), np.int64(2)), (np.int64(41), np.int64(220), np.int64(3)), (np.int64(41), np.int64(308), np.int64(3)), (np.int64(351), np.int64(207), np.int64(2)), (np.int64(351), np.int64(266), np.int64(2)), (np.int64(351), np.int64(220), np.int64(3)), (np.int64(351), np.int64(308), np.int64(3)), (np.int64(351), np.int64(286), np.int64(4)), (np.int64(207), np.int64(220), np.int64(1)), (np.int64(207), np.int64(308), np.int64(1)), (np.int64(207), np.int64(286), np.int64(2)), (np.int64(266), np.int64(220), np.int64(1)), (np.int64(266), np.int64(308), np.int64(1)), (np.int64(266), np.int64(286), np.int64(2)), (np.int64(220), np.int64(286), np.int64(1)), (np.int64(308), np.int64(286), np.int64(1))]
# [(np.int64(0), np.int64(18), np.int64(7))]
# [(np.int64(56), np.int64(0), np.int64(3))]
# [(np.int64(6), np.int64(46), np.int64(1))]
# [(np.int64(0), np.int64(205), np.int64(5)), (np.int64(0), np.int64(240), np.int64(7)), (np.int64(0), np.int64(348), np.int64(7)), (np.int64(0), np.int64(36), np.int64(8)), (np.int64(158), np.int64(205), np.int64(5)), (np.int64(158), np.int64(240), np.int64(7)), (np.int64(158), np.int64(348), np.int64(7)), (np.int64(158), np.int64(36), np.int64(8)), (np.int64(158), np.int64(192), np.int64(8)), (np.int64(205), np.int64(240), np.int64(2)), (np.int64(205), np.int64(348), np.int64(2)), (np.int64(205), np.int64(36), np.int64(3)), (np.int64(205), np.int64(192), np.int64(3)), (np.int64(205), np.int64(280), np.int64(3)), (np.int64(240), np.int64(36), np.int64(1)), (np.int64(240), np.int64(192), np.int64(1)), (np.int64(240), np.int64(280), np.int64(1)), (np.int64(240), np.int64(47), np.int64(3)), (np.int64(348), np.int64(36), np.int64(1)), (np.int64(348), np.int64(192), np.int64(1)), (np.int64(348), np.int64(280), np.int64(1)), (np.int64(348), np.int64(47), np.int64(3)), (np.int64(348), np.int64(314), np.int64(3)), (np.int64(36), np.int64(47), np.int64(2)), (np.int64(36), np.int64(314), np.int64(2)), (np.int64(36), np.int64(143), np.int64(3)), (np.int64(192), np.int64(47), np.int64(2)), (np.int64(192), np.int64(314), np.int64(2)), (np.int64(192), np.int64(143), np.int64(3)), (np.int64(192), np.int64(0), np.int64(4)), (np.int64(280), np.int64(47), np.int64(2)), (np.int64(280), np.int64(314), np.int64(2)), (np.int64(280), np.int64(143), np.int64(3)), (np.int64(280
64(43), np.int64(193), np.int64(5)), (np.int64(236), np.int64(174), np.int64(1)), (np.int64(236), np.int64(206), np.int64(1)), (np.int64(236), np.int64(193), np.int64(3)), (np.int64(236), np.int64(160), np.int64(4)), (np.int64(314), np.int64(174), np.int64(1)), (np.int64(314), np.int64(206), np.int64(1)), (np.int64(314), np.int64(193), np.int64(3)), (np.int64(314), np.int64(160), np.int64(4)), (np.int64(174), np.int64(193), np.int64(2)), (np.int64(174), np.int64(160), np.int64(3)), (np.int64(206), np.int64(193), np.int64(2)), (np.int64(206), np.int64(160), np.int64(3)), (np.int64(193), np.int64(160), np.int64(1))]
# [(np.int64(45), np.int64(0), np.int64(4))]
# [(np.int64(0), np.int64(20), np.int64(2)), (np.int64(0), np.int64(170), np.int64(6)), (np.int64(0), np.int64(60), np.int64(7)), (np.int64(0), np.int64(156), np.int64(10)), (np.int64(20), np.int64(170), np.int64(4)), (np.int64(20), np.int64(60), np.int64(5)), (np.int64(20), np.int64(156), np.int64(8)), (np.int64(20), np.int64(0), np.int64(9)), (np.int64(170), np.int64(60), np.int64(1)), (np.int64(170), np.int64(156), np.int64(4)), (np.int64(170), np.int64(0), np.int64(5)), (np.int64(170), np.int64(21), np.int64(9)), (np.int64(60), np.int64(156), np.int64(3)), (np.int64(60), np.int64(0), np.int64(4)), (np.int64(60), np.int64(21), np.int64(8)), (np.int64(156), np.int64(0), np.int64(1)), (np.int64(156), np.int64(21), np.int64(5)), (np.int64(0), np.int64(21), np.int64(4))]
# []
# [(np.int64(4), np.int64(21), np.int64(6))]
# [(np.int64(4), np.int64(40), np.int64(3))]
# [(np.int64(46), np.int64(5), np.int64(2))]
# []
# [(np.int64(158), np.int64(29), np.int64(2)), (np.int64(158), np.int64(0), np.int64(9)), (np.int64(29), np.int64(0), np.int64(7))]
# [(np.int64(3), np.int64(38), np.int64(1)), (np.int64(3), np.int64(88), np.int64(1)), (np.int64(25), np.int64(38), np.int64(1)), (np.int64(25), np.int64(88), np.int64(1))]
# [(np.int64(4), np.int64(19), np.int64(5)), (np.int64(4), np.int64(38), np.int64(5))]
# [(np.int64(5), np.int64(22), np.int64(4))]
# [(np.int64(37), np.int64(5), np.int64(9)), (np.int64(5), np.int64(36), np.int64(3)), (np.int64(5), np.int64(51), np.int64(3))]
# []
# []
# [(np.int64(0), np.int64(41), np.int64(5)), (np.int64(0), np.int64(196), np.int64(9)), (np.int64(41), np.int64(196), np.int64(4))]
# [(np.int64(40), np.int64(4), np.int64(3))]
# []
# [(np.int64(1), np.int64(89), np.int64(5)), (np.int64(1), np.int64(44), np.int64(7)), (np.int64(1), np.int64(60), np.int64(9)), (np.int64(1), np.int64(77), np.int64(9)), (np.int64(1), np.int64(142), np.int64(9)), (np.int64(89), np.int64(44), np.int64(2)), (np.int64(89), np.int64(60), np.int64(4)), (np.int64(89), np.int64(77), np.int64(4)), (np.int64(89), np.int64(142), np.int64(4)), (np.int64(89), np.int64(158), np.int64(4)), (np.int64(44), np.int64(60), np.int64(2)), (np.int64(44), np.int64(77), np.int64
.int64(7)), (np.int64(80), np.int64(112), np.int64(2)), (np.int64(80), np.int64(19), np.int64(4)), (np.int64(80), np.int64(0), np.int64(6)), (np.int64(212), np.int64(112), np.int64(2)), (np.int64(212), np.int64(19), np.int64(4)), (np.int64(212), np.int64(0), np.int64(6)), (np.int64(112), np.int64(19), np.int64(2)), (np.int64(112), np.int64(0), np.int64(4)), (np.int64(19), np.int64(0), np.int64(2))]
# []
# ч[(np.int64(378), np.int64(160), np.int64(1)), (np.int64(378), np.int64(322), np.int64(1)), (np.int64(378), np.int64(334), np.int64(1)), (np.int64(406), np.int64(160), np.int64(1)), (np.int64(406), np.int64(322), np.int64(1)), (np.int64(406), np.int64(334), np.int64(1)), (np.int64(406), np.int64(175), np.int64(2)), (np.int64(445), np.int64(160), np.int64(1)), (np.int64(445), np.int64(322), np.int64(1)), (np.int64(445), np.int64(334), np.int64(1)), (np.int64(445), np.int64(175), np.int64(2)), (np.int64(445), np.int64(246), np.int64(2)), (np.int64(160), np.int64(175), np.int64(1)), (np.int64(160), np.int64(246), np.int64(1)), (np.int64(160), np.int64(0), np.int64(2)), (np.int64(322), np.int64(175), np.int64(1)), (np.int64(322), np.int64(246), np.int64(1)), (np.int64(322), np.int64(0), np.int64(2)), (np.int64(322), np.int64(41), np.int64(2)), (np.int64(334), np.int64(175), np.int64(1)), (np.int64(334), np.int64(246), np.int64(1)), (np.int64(334), np.int64(0), np.int64(2)), (np.int64(334), np.int64(41), np.int64(2)), (np.int64(334), np.int64(351), np.int64(2)), (np.int64(175), np.int64(0), np.int64(1)), (np.int64(175), np.int64(41), np.int64(1)), (np.int64(175), np.int64(351), np.int64(1)), (np.int64(175), np.int64(207), np.int64(3)), (np.int64(246), np.int64(0), np.int64(1)), (np.int64(246), np.int64(41), np.int64(1)), (np.int64(246), np.int64(351), np.int64(1)), (np.int64(246), np.int64(207), np.int64(3)), (np.int64(246), np.int64(266), np.int64(3)), (np.int64(0), np.int64(207), np.int64(2)), (np.int64(0), np.int64(266), np.int64(2)), (np.int64(0), np.int64(220), np.int64(3)), (np.int64(41), np.int64(207), np.int64(2)), (np.int64(41), np.int64(266), np.int64(2)), (np.int64(41), np.int64(220), np.int64(3)), (np.int64(41), np.int64(308), np.int64(3)), (np.int64(351), np.int64(207), np.int64(2)), (np.int64(351), np.int64(266), np.int64(2)), (np.int64(351), np.int64(220), np.int64(3)), (np.int64(351), np.int64(308), np.int64(3)), (np.int64(351), np.int64(286), np.int64(4)), (np.int64(207), np.int64(220), np.int64(1)), (np.int64(207), np.int64(308), np.int64(1)), (np.int64(207), np.int64(286), np.int64(2)), (np.int64(266), np.int64(220), np.int64(1)), (np.int64(266), np.int64(308), np.int64(1)), (np.int64(266), np.int64(286), np.int64(2)), (np.int64(220), np.int64(286), np.int64(1)), (np.int64(308), np.int64(286), np.int64(1))]
# [(np.int64(0), np.int64(18), np.int64(7))]
# [(np.int64(56), np.int64(0), np.int64(3))]
# [(np.int64(6), np.int64(46), np.int64(1))]
# [(np.int64(4), np.int64(40), np.int64(3))]
# [(np.int64(46), np.int64(5), np.int64(2))]
# []
# [(np.int64(158), np.int64(29), np.int64(2)), (np.int64(158), np.int64(0), np.int64(9)), (np.int64(29), np.int64(0), np.int64(7))]
# [(np.int64(3), np.int64(38), np.int64(1)), (np.int64(3), np.int64(88), np.int64(1)), (np.int64(25), np.int64(38), np.int64(1)), (np.int64(25), np.int64(88), np.int64(1))]
# [(np.int64(4), np.int64(19), np.int64(5)), (np.int64(4), np.int64(38), np.int64(5))]
# [(np.int64(5), np.int64(22), np.int64(4))]
# [(np.int64(37), np.int64(5), np.int64(9)), (np.int64(5), np.int64(36), np.int64(3)), (np.int64(5), np.int64(51), np.int64(3))]
# []
# []
# [(np.int64(0), np.int64(41), np.int64(5)), (np.int64(0), np.int64(196), np.int64(9)), (np.int64(41), np.int64(196), np.int64(4))]
# [(np.int64(40), np.int64(4), np.int64(3))]
# []
# [(np.int64(1), np.int64(89), np.int64(5)), (np.int64(1), np.int64(44), np.int64(7)), (np.int64(1), np.int64(60), np.int64(9)), (np.int64(1), np.int64(77), np.int64(9)), (np.int64(1), np.int64(142), np.int64(9)), (np.int64(89), np.int64(44), np.int64(2)), (np.int64(89), np.int64(60), np.int64(4)), (np.int64(89), np.int64(77), np.int64(4)), (np.int64(89), np.int64(142), np.int64(4)), (np.int64(89), np.int64(158), np.int64(4)), (np.int64(44), np.int64(60), np.int64(2)), (np.int64(44), np.int64(77), np.int64(2)), (np.int64(44), np.int64(142), np.int64(2)), (np.int64(44), np.int64(158), np.int64(2)), (np.int64(44), np.int64(205), np.int64(2)), (np.int64(142), np.int64(176), np.int64(1)), (np.int64(158), np.int64(176), np.int64(1)), (np.int64(158), np.int64(22), np.int64(2)), (np.int64(205), np.int64(176), np.int64(1)), (np.int64(205), np.int64(22), np.int64(2)), (np.int64(205), np.int64(131), np.int64(2)), (np.int64(265), np.int64(176), np.int64(1)), (np.int64(265), np.int64(22), np.int64(2)), (np.int64(265), np.int64(131), np.int64(2)), (np.int64(265), np.int64(223), np.int64(2)), (np.int64(351), np.int64(176), np.int64(1)), (np.int64(351), np.int64(22), np.int64(2)), (np.int64(351), np.int64(131), np.int64(2)), (np.int64(351), np.int64(223), np.int64(2)), (np.int64(351), np.int64(246), np.int64(2)), (np.int64(176), np.int64(22), np.int64(1)), (np.int64(176), np.int64(131), np.int64(1)), (np.int64(176), np.int64(223), np.int64(1)), (np.int64(176), np.int64(246), np.int64(1))]
# [(np.int64(0), np.int64(159), np.int64(4)), (np.int64(0), np.int64(146), np.int64(6)), (np.int64(0), np.int64(247), np.int64(6)), (np.int64(0), np.int64(125), np.int64(8)), (np.int64(0), np.int64(195), np.int64(8)), (np.int64(159), np.int64(146), np.int64(2)), (np.int64(159), np.int64(247), np.int64(2)), (np.int64(159), np.int64(125), np.int64(4)), (np.int64(159), np.int64(195), np.int64(4)), (np.int64(159), np.int64(314), np.int64(4)), (np.int64(146), np.int64(125), np.int64(2)), (np.int64(146), np.int64(195), np.int64(2)), (np.int64
1)), (np.int64(175), np.int64(41), np.int64(1)), (np.int64(175), np.int64(351), np.int64(1)), (np.int64(175), np.int64(207), np.int64(3)), (np.int64(246), np.int64(0), np.int64(1)), (np.int64(246), np.int64(41), np.int64(1)), (np.int64(246), np.int64(351), np.int64(1)), (np.int64(246), np.int64(207), np.int64(3)), (np.int64(246), np.int64(266), np.int64(3)), (np.int64(0), np.int64(207), np.int64(2)), (np.int64(0), np.int64(266), np.int64(2)), (np.int64(0), np.int64(220), np.int64(3)), (np.int64(41), np.int64(207), np.int64(2)), (np.int64(41), np.int64(266), np.int64(2)), (np.int64(41), np.int64(220), np.int64(3)), (np.int64(41), np.int64(308), np.int64(3)), (np.int64(351), np.int64(207), np.int64(2)), (np.int64(351), np.int64(266), np.int64(2)), (np.int64(351), np.int64(220), np.int64(3)), (np.int64(351), np.int64(308), np.int64(3)), (np.int64(351), np.int64(286), np.int64(4)), (np.int64(207), np.int64(220), np.int64(1)), (np.int64(207), np.int64(308), np.int64(1)), (np.int64(207), np.int64(286), np.int64(2)), (np.int64(266), np.int64(220), np.int64(1)), (np.int64(266), np.int64(308), np.int64(1)), (np.int64(266), np.int64(286), np.int64(2)), (np.int64(220), np.int64(286), np.int64(1)), (np.int64(308), np.int64(286), np.int64(1))]
# [(np.int64(0), np.int64(18), np.int64(7))]
# [(np.int64(56), np.int64(0), np.int64(3))]
# [(np.int64(6), np.int64(46), np.int64(1))]
# [(np.int64(0), np.int64(205), np.int64(5)), (np.int64(0), np.int64(240), np.int64(7)), (np.int64(0), np.int64(348), np.int64(7)), (np.int64(0), np.int64(36), np.int64(8)), (np.int64(158), np.int64(205), np.int64(5)), (np.int64(158), np.int64(240), np.int64(7)), (np.int64(158), np.int64(348), np.int64(7)), (np.int64(158), np.int64(36), np.int64(8)), (np.int64(158), np.int64(192), np.int64(8)), (np.int64(205), np.int64(240), np.int64(2)), (np.int64(205), np.int64(348), np.int64(2)), (np.int64(205), np.int64(36), np.int64(3)), (np.int64(205), np.int64(192), np.int64(3)), (np.int64(205), np.int64(280), np.int64(3)), (np.int64(240), np.int64(36), np.int64(1)), (np.int64(240), np.int64(192), np.int64(1)), (np.int64(240), np.int64(280), np.int64(1)), (np.int64(240), np.int64(47), np.int64(3)), (np.int64(348), np.int64(36), np.int64(1)), (np.int64(348), np.int64(192), np.int64(1)), (np.int64(348), np.int64(280), np.int64(1)), (np.int64(348), np.int64(47), np.int64(3)), (np.int64(348), np.int64(314), np.int64(3)), (np.int64(36), np.int64(47), np.int64(2)), (np.int64(36), np.int64(314), np.int64(2)), (np.int64(36), np.int64(143), np.int64(3)), (np.int64(192), np.int64(47), np.int64(2)), (np.int64(192), np.int64(314), np.int64(2)), (np.int64(192), np.int64(143), np.int64(3)), (np.int64(192), np.int64(0), np.int64(4)), (np.int64(280), np.int64(47), np.int64(2)), (np.int64(280), np.int64(314), np.int64(2)), (np.int64(280), np.int64(143), np.int64(3)), (np.int64(280), np.int64(0), np.int64(4)), (np.int64(280), np.int64(177), np.int64(4)), (np.int64(47),
(236), np.int64(206), np.int64(1)), (np.int64(236), np.int64(193), np.int64(3)), (np.int64(236), np.int64(160), np.int64(4)), (np.int64(314), np.int64(174), np.int64(1)), (np.int64(314), np.int64(206), np.int64(1)), (np.int64(314), np.int64(193), np.int64(3)), (np.int64(314), np.int64(160), np.int64(4)), (np.int64(174), np.int64(193), np.int64(2)), (np.int64(174), np.int64(160), np.int64(3)), (np.int64(206), np.int64(193), np.int64(2)), (np.int64(206), np.int64(160), np.int64(3)), (np.int64(193), np.int64(160), np.int64(1))]
# [(np.int64(45), np.int64(0), np.int64(4))]
# [(np.int64(0), np.int64(20), np.int64(2)), (np.int64(0), np.int64(170), np.int64(6)), (np.int64(0), np.int64(60), np.int64(7)), (np.int64(0), np.int64(156), np.int64(10)), (np.int64(20), np.int64(170), np.int64(4)), (np.int64(20), np.int64(60), np.int64(5)), (np.int64(20), np.int64(156), np.int64(8)), (np.int64(20), np.int64(0), np.int64(9)), (np.int64(170), np.int64(60), np.int64(1)), (np.int64(170), np.int64(156), np.int64(4)), (np.int64(170), np.int64(0), np.int64(5)), (np.int64(170), np.int64(21), np.int64(9)), (np.int64(60), np.int64(156), np.int64(3)), (np.int64(60), np.int64(0), np.int64(4)), (np.int64(60), np.int64(21), np.int64(8)), (np.int64(156), np.int64(0), np.int64(1)), (np.int64(156), np.int64(21), np.int64(5)), (np.int64(0), np.int64(21), np.int64(4))]
# []
# [(np.int64(4), np.int64(21), np.int64(6))]
# [(np.int64(4), np.int64(40), np.int64(3))]
# [(np.int64(46), np.int64(5), np.int64(2))]
# []
# ...
# [(np.int64(0), np.int64(159), np.int64(4)), (np.int64(0), np.int64(146), np.int64(6)), (np.int64(0), np.int64(247), np.int64(6)), (np.int64(0), np.int64(125), np.int64(8)), (np.int64(0), np.int64(195), np.int64(8)), (np.int64(159), np.int64(146), np.int64(2)), (np.int64(159), np.int64(247), np.int64(2)), (np.int64(159), np.int64(125), np.int64(4)), (np.int64(159), np.int64(195), np.int64(4)), (np.int64(159), np.int64(314), np.int64(4)), (np.int64(146), np.int64(125), np.int64(2)), (np.int64(146), np.int64(195), np.int64(2)), (np.int64(146), np.int64(314), np.int64(2)), (np.int64(146), np.int64(46), np.int64(3)), (np.int64(247), np.int64(125), np.int64(2)), (np.int64(247), np.int64(195), np.int64(2)), (np.int64(247), np.int64(314), np.int64(2)), (np.int64(247), np.int64(46), np.int64(3)), (np.int64(247), np.int64(271), np.int64(3)), (np.int64(125), np.int64(46), np.int64(1)), (np.int64(125), np.int64(271), np.int64(1)), (np.int64(125), np.int64(299), np.int64(1)), (np.int64(195), np.int64(46), np.int64(1)), (np.int64(195), np.int64(271), np.int64(1)), (np.int64(195), np.int64(299), np.int64(1)), (np.int64(195), np.int64(381), np.int64(1)), (np.int64(314), np.int64(46), np.int64(1)), (np.int64(314), np.int64(271), np.int64(1)), (np.int64(314), np.int64(299), np.int64(1)), (np.int64(314), np.int64(381), np.int64(1)), (np.int64(314), np.int64(80), np.int64(2)), (np.int64(46), np.int64(80), np.int64(1)), (np.int64(46), np.int64(212), np.int64(1)), (np.int64(271), np.int64(80), np.int64(1)), (np.int64(271), np.int64(212), np.int64(1)), (np.int64(271), np.int64(112), np.int64(3)), (np.int64(299), np.int64(80), np.int64(1)), (np.int64(299), np.int64(212), np.int64(1)), (np.int64(299), np.int64(112), np.int64(3)), (np.int64(299), np.int64(19), np.int64(5)), (np.int64(381), np.int64(80), np.int64(1)), (np.int64(381), np.int64(212), np.int64(1)), (np.int64(381), np.int64(112), np.int64(3)), (np.int64(381), np.int64(19), np.int64(5)), (np.int64(381), np.int64(0), np.int64(7)), (np.int64(80), np.int64(112), np.int64(2)), (np.int64(80), np.int64(19), np.int64(4)), (np.int64(80), np.int64(0), np.int64(6)), (np.int64(212), np.int64(112), np.int64(2)), (np.int64(212), np.int64(19), np.int64(4)), (np.int64(212), np.int64(0), np.int64(6)), (np.int64(112), np.int64(19), np.int64(2)), (np.int64(112), np.int64(0), np.int64(4)), (np.int64(19), np.int64(0), np.int64(2))]
# []
# щ[(np.int64(378), np.int64(160), np.int64(1)), (np.int64(378), np.int64(322), np.int64(1)), (np.int64(378), np.int64(334), np.int64(1)), (np.int64(406), np.int64(160), np.int64(1)), (np.int64(406), np.int64(322), np.int64(1)), (np.int64(406), np.int64(334), np.int64(1)), (np.int64(406), np.int64(175), np.int64(2)), (np.int64(445), np.int64(160), np.int64(1)), (np.int64(445), np.int64(322), np.int64(1)), (np.int64(445), np.int64(334), np.int64(1)), (np.int64(445), np.int64(175), np.int64(2)), (np.int64(445), np.int64(246), np.int64(2)), (np.int64(160), np.int64(175), np.int64(1)), (np.int64(160), np.int64(246), np.int64(1)), (np.int64(160), np.int64(0), np.int64(2)), (np.int64(322), np.int64(175), np.int64(1)), (np.int64(322), np.int64(246), np.int64(1)), (np.int64(322), np.int64(0), np.int64(2)), (np.int64(322), np.int64(41), np.int64(2)), (np.int64(334), np.int64(175), np.int64(1)), (np.int64(334), np.int64(246), np.int64(1)), (np.int64(334), np.int64(0), np.int64(2)), (np.int64(334), np.int64(41), np.int64(2)), (np.int64(334), np.int64(351), np.int64(2)), (np.int64(175), np.int64(0), np.int64(1)), (np.int64(175), np.int64(41), np.int64(1)), (np.int64(175), np.int64(351), np.int64(1)), (np.int64(175), np.int64(207), np.int64(3)), (np.int64(246), np.int64(0), np.int64(1)), (np.int64(246), np.int64(41), np.int64(1)), (np.int64(246), np.int64(351), np.int64(1)), (np.int64(246), np.int64(207), np.int64(3)), (np.int64(246), np.int64(266), np.int64(3)), (np.int64(0), np.int64(207), np.int64(2)), (np.int64(0), np.int64(266), np.int64(2)), (np.int64(0), np.int64(220), np.int64(3)), (np.int64(41), np.int64(207), np.int64(2)), (np.int64(41), np.int64(266), np.int64(2)), (np.int64(41), np.int64(220), np.int64(3)), (np.int64(41), np.int64(308), np.int64(3)), (np.int64(351), np.int64(207), np.int64(2)), (np.int64(351), np.int64(266), np.int64(2)), (np.int64(351), np.int64(220), np.int64(3)), (np.int64(351), np.int64(308), np.int64(3)), (np.int64(351), np.int64(286), np.int64(4)), (np.int64(207), np.int64(220), np.int64(1)), (np.int64(207), np.int64(308), np.int64(1)), (np.int64(207), np.int64(286), np.int64(2)), (np.int64(266), np.int64(220), np.int64(1)), (np.int64(266), np.int64(308), np.int64(1)), (np.int64(266), np.int64(286), np.int64(2)), (np.int64(220), np.int64(286), np.int64(1)), (np.int64(308), np.int64(286), np.int64(1))]
# [(np.int64(0), np.int64(18), np.int64(7))]
# [(np.int64(56), np.int64(0), np.int64(3))]
# [(np.int64(6), np.int64(46), np.int64(1))]
# [(np.int64(0), np.int64(205), np.int64(5)), (np.int64(0), np.int64(240), np.int64(7)), (np.int64(0), np.int64(348), np.int64(7)), (np.int64(0), np.int64(36), np.int64(8)), (np.int64(158), np.int64(205), np.int64(5)), (np.int64(158), np.int64(240), np.int64(7)), (np.int64(158), np.int64(348), np.int64(7)), (np.int64(158), np.int64(36), np.int64(8)), (np.int64(158), np.int64(192), np.int64(8)), (np.int64(205), np.int64(240), np.int64(2)), (np.int64(205), np.int64(348), np.int64(2)), (np.int64(205), np.int64(36), np.int64(3)), (np.int64(205), np.int64(192), np.int64(3)), (np.int64(205), np.int64(280), np.int64(3)), (np.int64(240), np.int64(36), np.int64(1)), (np.int64(240), np.int64(192), np.int64(1)), (np.int64(240), np.int64(280), np.int64(1)), (np.int64(240), np.int64(47), np.int64(3)), (np.int64(348), np.int64(36), np.int64(1)), (np.int64(348), np.int64(192), np.int64(1)), (np.int64(348), np.int64(280), np.int64(1)), (np.int64(348), np.int64(47), np.int64(3)), (np.int64(348), np.int64(314), np.int64(3)), (np.int64(36), np.int64(47), np.int64(2)), (np.int64(36), np.int64(314), np.int64(2)), (np.int64(36), np.int64(143), np.int64(3)), (np.int64(192), np.int64(47), np.int64(2)), (np.int64(192), np.int64(314), np.int64(2)), (np.int64(192), np.int64(143), np.int64(3)), (np.int64(192), np.int64(0), np.int64(4)), (np.int64(280), np.int64(47), np.int64(2)), (np.int64(280), np.int64(314), np.int64(2)), (np.int64(280), np.int64(143), np.int64(3)), (np.int64(280), np.int64(0), np.int64(4)), (np.int64(280), np.int64(177), np.int64(4)), (np.int64(47), np.int64(143), np.int64(1)), (np.int64(47), np.int64(0), np.int64(2)), (np.int64(47), np.int64(177), np.int64(2)), (np.int64(47), np.int64(253), np.int64(2)), (np.int64(314), np.int64(143), np.int64(1)), (np.int64(314), np.int64(0), np.int64(2)), (np.int64(314), np.int64(177), np.int64(2)), (np.int64(314), np.int64(253), np.int64(2)), (np.int64(314), np.int64(225), np.int64(4)), (np.int64(143), np.int64(0), np.int64(1)), (np.int64(143), np.int64(177), np.int64(1)), (np.int64(143), np.int64(253), np.int64(1)), (np.int64(143), np.int64(225), np.int64(3)), (np.int64(143), np.int64(21), np.int64(5)), (np.int64(0), np.int64(225), np.int64(2)), (np.int64(0), np.int64(21), np.int64(4)), (np.int64(0), np.int64(112), np.int64(4)), (np.int64(177), np.int64(225), np.int64(2)), (np.int64(177), np.int64(21), np.int64(4)), (np.int64(177), np.int64(112), np.int64(4)), (np.
# [(np.int64(0), np.int64(20), np.int64(2)), (np.int64(0), np.int64(170), np.int64(6)), (np.int64(0), np.int64(60), np.int64(7)), (np.int64(0), np.int64(156), np.int64(10)), (np.int64(20), np.int64(170), np.int64(4)), (np.int64(20), np.int64(60), np.int64(5)), (np.int64(20), np.int64(156), np.int64(8)), (np.int64(20), np.int64(0), np.int64(9)), (np.int64(170), np.int64(60), np.int64(1)), (np.int64(170), np.int64(156), np.int64(4)), (np.int64(170), np.int64(0), np.int64(5)), (np.int64(170), np.int64(21), np.int64(9)), (np.int64(60), np.int64(156), np.int64(3)), (np.int64(60), np.int64(0), np.int64(4)), (np.int64(60), np.int64(21), np.int64(8)), (np.int64(156), np.int64(0), np.int64(1)), (np.int64(156), np.int64(21), np.int64(5)), (np.int64(0), np.int64(21), np.int64(4))]
# []
# [(np.int64(4), np.int64(21), np.int64(6))]
# [(np.int64(4), np.int64(40), np.int64(3))]
# [(np.int64(46), np.int64(5), np.int64(2))]
# []
# [(np.int64(158), np.int64(29), np.int64(2)), (np.int64(158), np.int64(0), np.int64(9)), (np.int64(29), np.int64(0), np.int64(7))]
# [(np.int64(3), np.int64(38), np.int64(1)), (np.int64(3), np.int64(88), np.int64(1)), (np.int64(25), np.int64(38), np.int64(1)), (np.int64(25), np.int64(88), np.int64(1))]
# [(np.int64(4), np.int64(19), np.int64(5)), (np.int64(4), np.int64(38), np.int64(5))]
# [(np.int64(5), np.int64(22), np.int64(4))]
# [(np.int64(37), np.int64(5), np.int64(9)), (np.int64(5), np.int64(36), np.int64(3)), (np.int64(5), np.int64(51), np.int64(3))]
# []
# []
# [(np.int64(0), np.int64(41), np.int64(5)), (np.int64(0), np.int64(196), np.int64(9)), (np.int64(41), np.int64(196), np.int64(4))]
# [(np.int64(40), np.int64(4), np.int64(3))]
# []
# [(np.int64(1), np.int64(89), np.int64(5)), (np.int64(1), np.int64(44), np.int64(7)), (np.int64(1), np.int64(60), np.int64(9)), (np.int64(1), np.int64(77), np.int64(9)), (np.int64(1), np.int64(142), np.int64(9)), (np.int64(89), np.int64(44), np.int64(2)), (np.int64(89), np.int64(60), np.int64(4)), (np.int64(89), np.int64(77), np.int64(4)), (np.int64(89), np.int64(142), np.int64(4)), (np.int64(89), np.int64(158), np.int64(4)), (np.int64(44), np.int64(60), np.int64(2)), (np.int64(44), np.int64(77), np.int64(2)), (np.int64(44), np.int64(142), np.int64(2)), (np.int64(44), np.int64(158), np.int64(2)), (np.int64(44), np.int64(205), np.int64(2)), (np.int64(142), np.int64(176), np.int64(1)), (np.int64(158), np.int64(176), np.int64(1)), (np.int64(158), np.int64(22), np.int64(2)), (np.int64(205), np.int64(176), np.int64(1)), (np.int64(205), np.int64(22), np.int64(2)), (np.int64(205), np.int64(131), np.int64(2)), (np.int64(265), np.int64(176), np.int64(1)), (np.int64(265), np.int64(22), np.int64(2)), (np.int64(265), np.int64(131), np.int64(2)), (np.int64(265), np.int64(223), np.int64(2)), (np.int64(351), np.int64(176), np.int64(1)), (np.int64(351), np.int64(22), np.int64(2)), (np.int64(351), np.int64(131), np.int64(2)), (np.int64(351), np.int64(223), np.int64(2)), (np.int64(351), np.int64(246), np.int64(2)), (np.int64(176), np.int64(22), np.int64(1)), (np.int64(176), np.int64(131), np.int64(1)), (np.int64(176), np.int64(223), np.int64(1)), (np.int64(176), np.int64(246), np.int64(1))]
# [(np.int64(0), np.int64(159), np.int64(4)), (np.int64(0), np.int64(146), np.int64(6)), (np.int64(0), np.int64(247), np.int64(6)), (np.int64(0), np.int64(125), np.int64(8)), (np.int64(0), np.int64(195), np.int64(8)), (np.int64(159), np.int64(146), np.int64(2)), (np.int64(159), np.int64(247), np.int64(2)), (np.int64(159), np.int64(125), np.int64(4)), (np.int64(159), np.int64(195), np.int64(4)), (np.int64(159), np.int64(314), np.int64(4)), (np.int64(146), np.int64(125), np.int64(2)), (np.int64(146), np.int64(195), np.int64(2)), (np.int64(146), np.int64(314), np.int64(2)), (np.int64(146), np.int64(46), np.int64(3)), (np.int64(247), np.int64(125), np.int64(2)), (np.int64(247), np.int64(195), np.int64(2)), (np.int64(247), np.int64(314), np.int64(2)), (np.int64(247), np.int64(46), np.int64(3)), (np.int64(247), np.int64(271), np.int64(3)), (np.int64(125), np.int64(46), np.int64(1)), (np.int64(125), np.int64(271), np.int64(1)), (np.int64(125), np.int64(299), np.int64(1)), (np.int64(195), np.int64(46), np.int64(1)), (np.int64(195), np.int64(271), np.int64(1)), (np.int64(195), np.int64(299), np.int64(1)), (np.int64(195), np.int64(381), np.int64(1)), (np.int64(314), np.int64(46), np.int64(1)), (np.int64(314), np.int64(271), np.int64(1)), (np.int64(314), np.int64(299), np.int64(1)), (np.int64(314), np.int64(381), np.int64(1)), (np.int64(314), np.int64(80), np.int64(2)), (np.int64(46), np.int64(80), np.int64(1)), (np.int64(46), np.int64(212), np.int64(1)), (np.int64(271), np.int64(80), np.int64(1)), (np.int64(271), np.int64(212), np.int64(1)), (np.int64(271), np.int64(112), np.int64(3)), (np.int64(299), np.int64(80), np.int64(1)), (np.int64(299), np.int64(212), np.int64(1)), (np.int64(299), np.int64(112), np.int64(3)), (np.int64(299), np.int64(19), np.int64(5)), (np.int64(381), np.int64(80), np.int64(1)), (np.int64(381), np.int64(212), np.int64(1)), (np.int64(381), np.int64(112), np.int64(3)), (np.int64(381), np.int64(19), np.int64(5)), (np.int64(381), np.int64(0), np.int64(7)), (np.int64(80), np.int64(112), np.int64(2)), (np.int64(80), np.int64(19), np.int64(4)), (np.int64(80), np.int64(0), np.int64(6)), (np.int64(212), np.int64(112), np.int64(2)), (np.int64(212), np.int64(19), np.int64(4)), (np.int64(212), np.int64(0), np.int64(6)), (np.int64(112), np.int64(19), np.int64(2)), (np.int64(112), np.int64(0), np.int64(4)), (np.int64(19), np.int64(0), np.int64(2))]
# []
# с

# %% [markdown]
# Сохраним отпечатки букв в один файл

# %%
import joblib

letters = glob.glob("../letters_source_files/*.wav")
fingerprints = pd.DataFrame(columns=['letter', 'fingerprint', 'audio_data'])
for letter in letters:
    # print(letter)
    audio_data, sr3 = load_audio(letter)
    letter_hash = extract_audio_fingerprint(letter)
    fingerprints.loc[len(fingerprints)] = {'letter': letter[24], 'fingerprint': letter_hash, 'audio_data': audio_data}
joblib.dump(fingerprints, 'audio_data.pkl')
# Out:
# ['audio_data.pkl']

# %%
fingerprints
# Out:
#    letter                                        fingerprint  \
# 0       с  [(378, 160, 1), (378, 322, 1), (378, 334, 1), ...
# 1       р                                       [(0, 18, 7)]
# 2       т                                       [(56, 0, 3)]
# 3       у                                       [(6, 46, 1)]
# 4       ч  [(0, 205, 5), (0, 240, 7), (0, 348, 7), (0, 36...
# 5       ц  [(383, 353, 2), (383, 0, 3), (383, 404, 4), (4...
# 6       ф                                       [(45, 0, 4)]
# 7       х  [(0, 20, 2), (0, 170, 6), (0, 60, 7), (0, 156,...
# 8       д                                                 []
# 9       ж                                       [(4, 21, 6)]
# 10      з                                       [(4, 40, 3)]
# 11      г                                       [(46, 5, 2)]
# 12      в                                                 []
# 13      а            [(158, 29, 2), (158, 0, 9), (29, 0, 7)]
# 14      -  [(3, 38, 1), (3, 88, 1), (25, 38, 1), (25, 88,...
# 15      б                           [(4, 19, 5), (4, 38, 5)]
# 16      м                                       [(5, 22, 4)]
# 17      н               [(37, 5, 9), (5, 36, 3), (5, 51, 3)]
# 18      п                                                 []
# 19      о                                                 []
# 20      к            [(0, 41, 5), (0, 196, 9), (41, 196, 4)]
# 21      л                                       [(40, 4, 3)]
# 22      и                                                 []
# 23      ш  [(1, 89, 5), (1, 44, 7), (1, 60, 9), (1, 77, 9...
# 24      щ  [(0, 159, 4), (0, 146, 6), (0, 247, 6), (0, 12...
# 25      ы                                                 []
#
#                                            audio_data
# 0   [0.111094765, 0.11468667, 0.11332093, 0.113765...
# 1   [-0.1123731, -0.1136767, -0.11559798, -0.12133...
# 2   [0.10897091, 0.10664665, 0.10353996, 0.1056936...
# 3   [0.4839898, 0.47998083, 0.4888156, 0.49532044,...
# 4   [-0.08081355, -0.08378393, -0.08002379, -0.074...
# 5   [0.011066696, 0.011330579, 0.012532522, 0.0115...
# 6   [0.0037311371, 0.0032724375, 0.0024138466, 0.0...
# 7   [0.03742265, 0.038092654, 0.037513778, 0.03705...
# 8   [0.49027663, 0.48503, 0.4989879, 0.50639945, 0...
# 9   [0.21585082, 0.22312501, 0.22149055, 0.2217841...
# 10  [-0.0469338, -0.05621418, -0.0564737, -0.05166...
# 11  [-0.23730692, -0.24458247, -0.2540415, -0.2623...
# 12  [0.1757872, 0.17942713, 0.17700963, 0.17900805...
# 13  [-0.060495168, -0.06169343, -0.056217592, -0.0...
# 14  [-0.0014648438, -0.00048828125, -0.000579834, ...
# 15  [-0.6782451, -0.7080017, -0.7195578, -0.735237...
# 16  [0.43459532, 0.4307177, 0.42628577, 0.42517546...
# 17  [-0.48005053, -0.4893418, -0.49605516, -0.5029...
# 18  [0.20135008, 0.19412597, 0.19757642, 0.2036831...
# 19  [-0.107720725, -0.10629893, -0.10615884, -0.10...
# 20  [-0.12690261, -0.1273751, -0.13000728, -0.1305...
# 21  [0.10231864, 0.09964951, 0.09865935, 0.0980585...
# 22  [0.69418174, 0.66143256, 0.6535779, 0.639416, ...
# 23  [0.025104651, 0.029346056, 0.027666979, 0.0253...
# 24  [0.026758704, 0.028123422, 0.027325304, 0.0282...
# 25  [-0.017500881, -0.023673467, -0.026339835, -0....
