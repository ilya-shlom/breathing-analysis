# %% [markdown]
# ### Кластеризация дыхания по активностям

# %%
import pandas as pd
from matplotlib import pyplot as plt
import numpy as np
import librosa
import glob
from itertools import chain

# %% [markdown]
# ### Загрузка файлов

# %%
activities = ['Dyspnea', 'Running', 'Sitting', 'Squats', 'Standing', 'Walking']
wavs = {}
for activity in activities:
    wavs[activity] = glob.glob(f'../web_recordings/{activity}/audio/*.wav')

wavs_list = list(chain(*wavs.values()))
wavs_list
# Out:
# ['../web_recordings/Dyspnea/audio/Dyspnea_exhale_3.wav',
#  '../web_recordings/Dyspnea/audio/Dyspnea_exhale_2.wav',
#  '../web_recordings/Dyspnea/audio/Dyspnea_exhale_1.wav',
#  '../web_recordings/Dyspnea/audio/Dyspnea_exhale_5.wav',
#  '../web_recordings/Dyspnea/audio/Dyspnea_exhale_4.wav',
#  '../web_recordings/Dyspnea/audio/Dyspnea_exhale_6.wav',
#  '../web_recordings/Dyspnea/audio/Dyspnea_exhale_7.wav',
#  '../web_recordings/Dyspnea/audio/Dyspnea_inhale_6.wav',
#  '../web_recordings/Dyspnea/audio/Dyspnea_inhale_7.wav',
#  '../web_recordings/Dyspnea/audio/Dyspnea_inhale_5.wav',
#  '../web_recordings/Dyspnea/audio/Dyspnea_inhale_4.wav',
#  '../web_recordings/Dyspnea/audio/Dyspnea_inhale_1.wav',
#  '../web_recordings/Dyspnea/audio/Dyspnea_inhale_3.wav',
#  '../web_recordings/Dyspnea/audio/Dyspnea_inhale_2.wav',
#  '../web_recordings/Dyspnea/audio/Dyspnea_inhale_9.wav',
#  '../web_recordings/Dyspnea/audio/Dyspnea_inhale_8.wav',
#  '../web_recordings/Dyspnea/audio/Dyspnea_exhale_9.wav',
#  '../web_recordings/Dyspnea/audio/Dyspnea_exhale_8.wav',
#  '../web_recordings/Dyspnea/audio/Dyspnea_inhale_10.wav',
#  '../web_recordings/Dyspnea/audio/Dyspnea_exhale_10.wav',
#  '../web_recordings/Running/audio/Running_inhale_8.wav',
#  '../web_recordings/Running/audio/Running_inhale_9.wav',
#  '../web_recordings/Running/audio/Running_exhale_8.wav',
#  '../web_recordings/Running/audio/Running_exhale_9.wav',
#  '../web_recordings/Running/audio/Running_exhale_4.wav',
#  '../web_recordings/Running/audio/Running_exhale_5.wav',
#  '../web_recordings/Running/audio/Running_exhale_7.wav',
#  '../web_recordings/Running/audio/Running_exhale_6.wav',
#  '../web_recordings/Running/audio/Running_exhale_2.wav',
#  '../web_recordings/Running/audio/Running_exhale_3.wav',
#  '../web_recordings/Running/audio/Running_exhale_10.wav',
#  '../web_recordings/Running/audio/Running_exhale_1.wav',
#  '../web_recordings/Running/audio/Running_inhale_10.wav',
#  '../web_recordings/Running/audio/Running_inhale_1.wav',
#  '../web_recordings/Running/audio/Running_inhale_2.wav',
#  '../web_recordings/Running/audio/Running_inhale_3.wav',
#  '../web_recordings/Running/audio/Running_inhale_7.wav',
#  '../web_recordings/Running/audio/Running_inhale_6.wav',
#  '../web_recordings/Running/audio/Running_inhale_4.wav',
#  '../web_recordings/Running/audio/Running_inhale_5.wav',
#  '../web_recordings/Sitting/audio/Sitting_inhale_2.wav',
#  '../web_recordings/Sitting/audio/Sitting_inhale_3.wav',
#  '../web_recordings/Sitting/audio/Sitting_inhale_1.wav',
#  '../web_recordings/Sitting/audio/Sitting_inhale_4.wav',
#  '../web_recordings/Sitting/audio/Sitting_inhale_5.wav',
#  '../web_recordings/Sitting/audio/Sitting_inhale_7.wav',
#  '../web_recordings/Sitting/audio/Sitting_inhale_6.wav',
#  '../web_recordings/Sitting/audio/Sitting_exhale_7.wav',
#  '../web_recordings/Sitting/audio/Sitting_exhale_6.wav',
#  '../web_recordings/Sitting/audio/Sitting_exhale_4.wav',
#  '../web_recordings/Sitting/audio/Sitting_exhale_5.wav',
#  '../web_recordings/Sitting/audio/Sitting_exhale_1.wav',
#  '../web_recordings/Sitting/audio/Sitting_exhale_2.wav',
#  '../web_recordings/Sitting/audio/Sitting_exhale_3.wav',
#  '../web_recordings/Sitting/audio/Sitting_exhale_10.wav',
#  '../web_recordings/Sitting/audio/Sitting_inhale_10.wav',
#  '../web_recordings/Sitting/audio/Sitting_exhale_8.wav',
#  '../web_recordings/Sitting/audio/Sitting_exhale_9.wav',
#  '../web_recordings/Sitting/audio/Sitting_inhale_8.wav',
#  '../web_recordings/Sitting/audio/Sitting_inhale_9.wav',
#  '../web_recordings/Squats/audio/Squats_inhale_8.wav',
#  '../web_recordings/Squats/audio/Squats_inhale_9.wav',
#  '../web_recordings/Squats/audio/Squats_inhale_10.wav',
#  '../web_recordings/Squats/audio/Squats_exhale_10.wav',
#  '../web_recordings/Squats/audio/Squats_exhale_8.wav',
#  '../web_recordings/Squats/audio/Squats_exhale_9.wav',
#  '../web_recordings/Squats/audio/Squats_exhale_7.wav',
#  '../web_recordings/Squats/audio/Squats_exhale_6.wav',
#  '../web_recordings/Squats/audio/Squats_exhale_4.wav',
#  '../web_recordings/Squats/audio/Squats_exhale_5.wav',
#  '../web_recordings/Squats/audio/Squats_exhale_1.wav',
#  '../web_recordings/Squats/audio/Squats_exhale_2.wav',
#  '../web_recordings/Squats/audio/Squats_exhale_3.wav',
#  '../web_recordings/Squats/audio/Squats_inhale_2.wav',
#  '../web_recordings/Squats/audio/Squats_inhale_3.wav',
#  '../web_recordings/Squats/audio/Squats_inhale_1.wav',
#  '../web_recordings/Squats/audio/Squats_inhale_4.wav',
#  '../web_recordings/Squats/audio/Squats_inhale_5.wav',
#  '../web_recordings/Squats/audio/Squats_inhale_7.wav',
#  '../web_recordings/Squats/audio/Squats_inhale_6.wav',
#  '../web_recordings/Standing/audio/Standing_exhale_10.wav',
#  '../web_recordings/Standing/audio/Standing_inhale_7.wav',
#  '../web_recordings/Standing/audio/Standing_inhale_10.wav',
#  '../web_recordings/Standing/audio/Standing_inhale_6.wav',
#  '../web_recordings/Standing/audio/Standing_inhale_4.wav',
#  '../web_recordings/Standing/audio/Standing_inhale_5.wav',
#  '../web_recordings/Standing/audio/Standing_inhale_1.wav',
#  '../web_recordings/Standing/audio/Standing_inhale_2.wav',
#  '../web_recordings/Standing/audio/Standing_inhale_3.wav',
#  '../web_recordings/Standing/audio/Standing_exhale_2.wav',
#  '../web_recordings/Standing/audio/Standing_exhale_3.wav',
#  '../web_recordings/Standing/audio/Standing_exhale_1.wav',
#  '../web_recordings/Standing/audio/Standing_exhale_4.wav',
#  '../web_recordings/Standing/audio/Standing_exhale_5.wav',
#  '../web_recordings/Standing/audio/Standing_exhale_7.wav',
#  '../web_recordings/Standing/audio/Standing_exhale_6.wav',
#  '../web_recordings/Standing/audio/Standing_exhale_8.wav',
#  '../web_recordings/Standing/audio/Standing_exhale_9.wav',
#  '../web_recordings/Standing/audio/Standing_inhale_8.wav',
#  '../web_recordings/Standing/audio/Standing_inhale_9.wav',
#  '../web_recordings/Walking/audio/Walking_exhale_1.wav',
#  '../web_recordings/Walking/audio/Walking_exhale_3.wav',
#  '../web_recordings/Walking/audio/Walking_exhale_2.wav',
#  '../web_recordings/Walking/audio/Walking_exhale_6.wav',
#  '../web_recordings/Walking/audio/Walking_exhale_7.wav',
#  '../web_recordings/Walking/audio/Walking_exhale_5.wav',
#  '../web_recordings/Walking/audio/Walking_exhale_4.wav',
#  '../web_recordings/Walking/audio/Walking_inhale_5.wav',
#  '../web_recordings/Walking/audio/Walking_inhale_4.wav',
#  '../web_recordings/Walking/audio/Walking_inhale_6.wav',
#  '../web_recordings/Walking/audio/Walking_inhale_7.wav',
#  '../web_recordings/Walking/audio/Walking_inhale_3.wav',
#  '../web_recordings/Walking/audio/Walking_inhale_2.wav',
#  '../web_recordings/Walking/audio/Walking_inhale_1.wav',
#  '../web_recordings/Walking/audio/Walking_inhale_10.wav',
#  '../web_recordings/Walking/audio/Walking_exhale_10.wav',
#  '../web_recordings/Walking/audio/Walking_inhale_9.wav',
#  '../web_recordings/Walking/audio/Walking_inhale_8.wav',
#  '../web_recordings/Walking/audio/Walking_exhale_9.wav',
#  '../web_recordings/Walking/audio/Walking_exhale_8.wav']

# %%
from tools import get_features

df = get_features.get_features_frame(wavs_list, 2)
df = df.transpose()
df
# Out:
# ../web_recordings/Dyspnea/audio/Dyspnea_exhale_3.wav duration = 2.04 seconds
# 40 frames, 68 short-term features
# ../web_recordings/Dyspnea/audio/Dyspnea_exhale_2.wav duration = 2.1 seconds
# 42 frames, 68 short-term features
# ../web_recordings/Dyspnea/audio/Dyspnea_exhale_1.wav duration = 2.22 seconds
# 44 frames, 68 short-term features
# ../web_recordings/Dyspnea/audio/Dyspnea_exhale_5.wav duration = 2.4 seconds
# 48 frames, 68 short-term features
# ../web_recordings/Dyspnea/audio/Dyspnea_exhale_4.wav duration = 2.28 seconds
# 45 frames, 68 short-term features
# ../web_recordings/Dyspnea/audio/Dyspnea_exhale_6.wav duration = 1.98 seconds
# 39 frames, 68 short-term features
# ../web_recordings/Dyspnea/audio/Dyspnea_exhale_7.wav duration = 2.4 seconds
# 48 frames, 68 short-term features
# ../web_recordings/Dyspnea/audio/Dyspnea_inhale_6.wav duration = 2.04 seconds
# 40 frames, 68 short-term features
# ../web_recordings/Dyspnea/audio/Dyspnea_inhale_7.wav duration = 2.1 seconds
# 42 frames, 68 short-term features
# ../web_recordings/Dyspnea/audio/Dyspnea_inhale_5.wav duration = 2.46 seconds
# 49 frames, 68 short-term features
# ../web_recordings/Dyspnea/audio/Dyspnea_inhale_4.wav duration = 2.28 seconds
# 45 frames, 68 short-term features
# ../web_recordings/Dyspnea/audio/Dyspnea_inhale_1.wav duration = 1.74 seconds
# 34 frames, 68 short-term features
# ../web_recordings/Dyspnea/audio/Dyspnea_inhale_3.wav duration = 1.74 seconds
# 34 frames, 68 short-term features
# ../web_recordings/Dyspnea/audio/Dyspnea_inhale_2.wav duration = 1.92 seconds
# 38 frames, 68 short-term features
# ../web_recordings/Dyspnea/audio/Dyspnea_inhale_9.wav duration = 1.86 seconds
# 37 frames, 68 short-term features
# ../web_recordings/Dyspnea/audio/Dyspnea_inhale_8.wav duration = 1.8 seconds
# 36 frames, 68 short-term features
# ../web_recordings/Dyspnea/audio/Dyspnea_exhale_9.wav duration = 1.92 seconds
# 38 frames, 68 short-term features
# ../web_recordings/Dyspnea/audio/Dyspnea_exhale_8.wav duration = 1.86 seconds
# 37 frames, 68 short-term features
# ../web_recordings/Dyspnea/audio/Dyspnea_inhale_10.wav duration = 1.74 seconds
# 34 frames, 68 short-term features
# ../web_recordings/Dyspnea/audio/Dyspnea_exhale_10.wav duration = 2.1 seconds
# 42 frames, 68 short-term features
# ../web_recordings/Running/audio/Running_inhale_8.wav duration = 1.6206349206349207 seconds
# 32 frames, 68 short-term features
# ../web_recordings/Running/audio/Running_inhale_9.wav duration = 1.14 seconds
# 22 frames, 68 short-term features
# ../web_recordings/Running/audio/Running_exhale_8.wav duration = 1.6206349206349207 seconds
# 32 frames, 68 short-term features
# ../web_recordings/Running/audio/Running_exhale_9.wav duration = 1.44 seconds
# 28 frames, 68 short-term features
# ../web_recordings/Running/audio/Running_exhale_4.wav duration = 1.44 seconds
# 28 frames, 68 short-term features
# ../web_recordings/Running/audio/Running_exhale_5.wav duration = 1.14 seconds
# 22 frames, 68 short-term features
# ../web_recordings/Running/audio/Running_exhale_7.wav duration = 1.6206349206349207 seconds
# 32 frames, 68 short-term features
# ../web_recordings/Running/audio/Running_exhale_6.wav duration = 1.32 seconds
# 26 frames, 68 short-term features
# ../web_recordings/Running/audio/Running_exhale_2.wav duration = 1.56 seconds
# 31 frames, 68 short-term features
# ../web_recordings/Running/audio/Running_exhale_3.wav duration = 0.9 seconds
# 18 frames, 68 short-term features
# ../web_recordings/Running/audio/Running_exhale_10.wav duration = 1.08 seconds
# 21 frames, 68 short-term features
# ../web_recordings/Running/audio/Running_exhale_1.wav duration = 1.5 seconds
# 30 frames, 68 short-term features
# ../web_recordings/Running/audio/Running_inhale_10.wav duration = 1.68 seconds
# 33 frames, 68 short-term features
# ../web_recordings/Running/audio/Running_inhale_1.wav duration = 1.6206349206349207 seconds
# 32 frames, 68 short-term features
# ../web_recordings/Running/audio/Running_inhale_2.wav duration = 1.2 seconds
# 24 frames, 68 short-term features
# ../web_recordings/Running/audio/Running_inhale_3.wav duration = 1.14 seconds
# 22 frames, 68 short-term features
# ../web_recordings/Running/audio/Running_inhale_7.wav duration = 1.32 seconds
# 26 frames, 68 short-term features
# ../web_recordings/Running/audio/Running_inhale_6.wav duration = 1.44 seconds
# 28 frames, 68 short-term features
# ../web_recordings/Running/audio/Running_inhale_4.wav duration = 1.44 seconds
# 28 frames, 68 short-term features
# ../web_recordings/Running/audio/Running_inhale_5.wav duration = 1.2 seconds
# 24 frames, 68 short-term features
# ../web_recordings/Sitting/audio/Sitting_inhale_2.wav duration = 2.1 seconds
# 42 frames, 68 short-term features
# ../web_recordings/Sitting/audio/Sitting_inhale_3.wav duration = 2.64 seconds
# 52 frames, 68 short-term features
# ../web_recordings/Sitting/audio/Sitting_inhale_1.wav duration = 2.7 seconds
# 54 frames, 68 short-term features
# ../web_recordings/Sitting/audio/Sitting_inhale_4.wav duration = 2.64 seconds
# 52 frames, 68 short-term features
# ../web_recordings/Sitting/audio/Sitting_inhale_5.wav duration = 2.58 seconds
# 51 frames, 68 short-term features
# ../web_recordings/Sitting/audio/Sitting_inhale_7.wav duration = 2.34 seconds
# 46 frames, 68 short-term features
# ../web_recordings/Sitting/audio/Sitting_inhale_6.wav duration = 2.46 seconds
# 49 frames, 68 short-term features
# ../web_recordings/Sitting/audio/Sitting_exhale_7.wav duration = 2.7 seconds
# 54 frames, 68 short-term features
# ../web_recordings/Sitting/audio/Sitting_exhale_6.wav duration = 2.82 seconds
# 56 frames, 68 short-term features
# ../web_recordings/Sitting/audio/Sitting_exhale_4.wav duration = 2.88 seconds
# 57 frames, 68 short-term features
# ../web_recordings/Sitting/audio/Sitting_exhale_5.wav duration = 2.94 seconds
# 58 frames, 68 short-term features
# ../web_recordings/Sitting/audio/Sitting_exhale_1.wav duration = 2.76 seconds
# 55 frames, 68 short-term features
# ../web_recordings/Sitting/audio/Sitting_exhale_2.wav duration = 2.7 seconds
# 54 frames, 68 short-term features
# ../web_recordings/Sitting/audio/Sitting_exhale_3.wav duration = 2.34 seconds
# 46 frames, 68 short-term features
# ../web_recordings/Sitting/audio/Sitting_exhale_10.wav duration = 2.52 seconds
# 50 frames, 68 short-term features
# ../web_recordings/Sitting/audio/Sitting_inhale_10.wav duration = 2.82 seconds
# 56 frames, 68 short-term features
# ../web_recordings/Sitting/audio/Sitting_exhale_8.wav duration = 2.4 seconds
# 48 frames, 68 short-term features
# ../web_recordings/Sitting/audio/Sitting_exhale_9.wav duration = 2.64 seconds
# 52 frames, 68 short-term features
# ../web_recordings/Sitting/audio/Sitting_inhale_8.wav duration = 2.4 seconds
# 48 frames, 68 short-term features
# ../web_recordings/Sitting/audio/Sitting_inhale_9.wav duration = 2.22 seconds
# 44 frames, 68 short-term features
# ../web_recordings/Squats/audio/Squats_inhale_8.wav duration = 1.02 seconds
# 20 frames, 68 short-term features
# ../web_recordings/Squats/audio/Squats_inhale_9.wav duration = 0.78 seconds
# 15 frames, 68 short-term features
# ../web_recordings/Squats/audio/Squats_inhale_10.wav duration = 1.38 seconds
# 27 frames, 68 short-term features
# ../web_recordings/Squats/audio/Squats_exhale_10.wav duration = 1.08 seconds
# 21 frames, 68 short-term features
# ../web_recordings/Squats/audio/Squats_exhale_8.wav duration = 1.32 seconds
# 26 frames, 68 short-term features
# ../web_recordings/Squats/audio/Squats_exhale_9.wav duration = 1.5 seconds
# 30 frames, 68 short-term features
# ../web_recordings/Squats/audio/Squats_exhale_7.wav duration = 1.14 seconds
# 22 frames, 68 short-term features
# ../web_recordings/Squats/audio/Squats_exhale_6.wav duration = 1.44 seconds
# 28 frames, 68 short-term features
# ../web_recordings/Squats/audio/Squats_exhale_4.wav duration = 2.16 seconds
# 43 frames, 68 short-term features
# ../web_recordings/Squats/audio/Squats_exhale_5.wav duration = 1.68 seconds
# 33 frames, 68 short-term features
# ../web_recordings/Squats/audio/Squats_exhale_1.wav duration = 1.68 seconds
# 33 frames, 68 short-term features
# ../web_recordings/Squats/audio/Squats_exhale_2.wav duration = 2.04 seconds
# 40 frames, 68 short-term features
# ../web_recordings/Squats/audio/Squats_exhale_3.wav duration = 1.68 seconds
# 33 frames, 68 short-term features
# ../web_recordings/Squats/audio/Squats_inhale_2.wav duration = 1.2 seconds
# 24 frames, 68 short-term features
# ../web_recordings/Squats/audio/Squats_inhale_3.wav duration = 1.08 seconds
# 21 frames, 68 short-term features
# ../web_recordings/Squats/audio/Squats_inhale_1.wav duration = 2.04 seconds
# 40 frames, 68 short-term features
# ../web_recordings/Squats/audio/Squats_inhale_4.wav duration = 1.38 seconds
# 27 frames, 68 short-term features
# ../web_recordings/Squats/audio/Squats_inhale_5.wav duration = 1.08 seconds
# 21 frames, 68 short-term features
# ../web_recordings/Squats/audio/Squats_inhale_7.wav duration = 1.2 seconds
# 24 frames, 68 short-term features
# ../web_recordings/Squats/audio/Squats_inhale_6.wav duration = 1.92 seconds
# 38 frames, 68 short-term features
# ../web_recordings/Standing/audio/Standing_exhale_10.wav duration = 2.34 seconds
# 46 frames, 68 short-term features
# ../web_recordings/Standing/audio/Standing_inhale_7.wav duration = 2.52 seconds
# 50 frames, 68 short-term features
# ../web_recordings/Standing/audio/Standing_inhale_10.wav duration = 2.04 seconds
# 40 frames, 68 short-term features
# ../web_recordings/Standing/audio/Standing_inhale_6.wav duration = 2.76 seconds
# 55 frames, 68 short-term features
# ../web_recordings/Standing/audio/Standing_inhale_4.wav duration = 2.58 seconds
# 51 frames, 68 short-term features
# ../web_recordings/Standing/audio/Standing_inhale_5.wav duration = 2.94 seconds
# 58 frames, 68 short-term features
# ../web_recordings/Standing/audio/Standing_inhale_1.wav duration = 3.18 seconds
# 63 frames, 68 short-term features
# ../web_recordings/Standing/audio/Standing_inhale_2.wav duration = 3.12 seconds
# 62 frames, 68 short-term features
# ../web_recordings/Standing/audio/Standing_inhale_3.wav duration = 3.18 seconds
# 63 frames, 68 short-term features
# ../web_recordings/Standing/audio/Standing_exhale_2.wav duration = 3.0 seconds
# 60 frames, 68 short-term features
# ../web_recordings/Standing/audio/Standing_exhale_3.wav duration = 3.18 seconds
# 63 frames, 68 short-term features
# ../web_recordings/Standing/audio/Standing_exhale_1.wav duration = 3.48 seconds
# 69 frames, 68 short-term features
# ../web_recordings/Standing/audio/Standing_exhale_4.wav duration = 2.88 seconds
# 57 frames, 68 short-term features
# ../web_recordings/Standing/audio/Standing_exhale_5.wav duration = 2.64 seconds
# 52 frames, 68 short-term features
# ../web_recordings/Standing/audio/Standing_exhale_7.wav duration = 3.06 seconds
# 61 frames, 68 short-term features
# ../web_recordings/Standing/audio/Standing_exhale_6.wav duration = 3.3 seconds
# 66 frames, 68 short-term features
# ../web_recordings/Standing/audio/Standing_exhale_8.wav duration = 2.64 seconds
# 52 frames, 68 short-term features
# ../web_recordings/Standing/audio/Standing_exhale_9.wav duration = 2.94 seconds
# 58 frames, 68 short-term features
# ../web_recordings/Standing/audio/Standing_inhale_8.wav duration = 2.52 seconds
# 50 frames, 68 short-term features
# ../web_recordings/Standing/audio/Standing_inhale_9.wav duration = 2.16 seconds
# 43 frames, 68 short-term features
# ../web_recordings/Walking/audio/Walking_exhale_1.wav duration = 2.7 seconds
# 54 frames, 68 short-term features
# ../web_recordings/Walking/audio/Walking_exhale_3.wav duration = 2.7 seconds
# 54 frames, 68 short-term features
# ../web_recordings/Walking/audio/Walking_exhale_2.wav duration = 2.4 seconds
# 48 frames, 68 short-term features
# ../web_recordings/Walking/audio/Walking_exhale_6.wav duration = 2.7 seconds
# 54 frames, 68 short-term features
# ../web_recordings/Walking/audio/Walking_exhale_7.wav duration = 2.76 seconds
# 55 frames, 68 short-term features
# ../web_recordings/Walking/audio/Walking_exhale_5.wav duration = 3.2402267573696144 seconds
# 64 frames, 68 short-term features
# ../web_recordings/Walking/audio/Walking_exhale_4.wav duration = 2.7 seconds
# 54 frames, 68 short-term features
# ../web_recordings/Walking/audio/Walking_inhale_5.wav duration = 2.46 seconds
# 49 frames, 68 short-term features
# ../web_recordings/Walking/audio/Walking_inhale_4.wav duration = 3.2402267573696144 seconds
# 64 frames, 68 short-term features
# ../web_recordings/Walking/audio/Walking_inhale_6.wav duration = 2.76 seconds
# 55 frames, 68 short-term features
# ../web_recordings/Walking/audio/Walking_inhale_7.wav duration = 2.76 seconds
# 55 frames, 68 short-term features
# ../web_recordings/Walking/audio/Walking_inhale_3.wav duration = 2.4 seconds
# 48 frames, 68 short-term features
# ../web_recordings/Walking/audio/Walking_inhale_2.wav duration = 2.76 seconds
# 55 frames, 68 short-term features
# ../web_recordings/Walking/audio/Walking_inhale_1.wav duration = 2.76 seconds
# 55 frames, 68 short-term features
# ../web_recordings/Walking/audio/Walking_inhale_10.wav duration = 2.82 seconds
# 56 frames, 68 short-term features
# ../web_recordings/Walking/audio/Walking_exhale_10.wav duration = 2.88 seconds
# 57 frames, 68 short-term features
# ../web_recordings/Walking/audio/Walking_inhale_9.wav duration = 3.3 seconds
# 66 frames, 68 short-term features
# ../web_recordings/Walking/audio/Walking_inhale_8.wav duration = 2.52 seconds
# 50 frames, 68 short-term features
# ../web_recordings/Walking/audio/Walking_exhale_9.wav duration = 3.18 seconds
# 63 frames, 68 short-term features
# ../web_recordings/Walking/audio/Walking_exhale_8.wav duration = 3.48 seconds
# 69 frames, 68 short-term features
#                        0         1         2         3         4         5    \
# Dyspnea_exhale_3.wav   0.0  0.012806  3.317673  0.002670  0.029585  0.000113
# Dyspnea_exhale_2.wav   0.0  0.000804  3.317594  0.007379  0.062256  0.000188
# Dyspnea_exhale_1.wav   0.0  0.010515  3.317643  0.002303  0.028619  0.000002
# Dyspnea_exhale_5.wav   0.0  0.012740  3.317729  0.002582  0.029792  0.000094
# Dyspnea_exhale_4.wav   0.0  0.000469  3.317633  0.006905  0.056993  0.001146
# ...                    ...       ...       ...       ...       ...       ...
# Walking_exhale_10.wav  0.0  0.002698  3.317677  0.003698  0.039918  0.000023
# Walking_inhale_9.wav   0.0  0.008702  3.317718  0.002517  0.030538  0.000007
# Walking_inhale_8.wav   0.0  0.011694  3.317635  0.002565  0.029961  0.000010
# Walking_exhale_9.wav   0.0  0.006850  3.317664  0.003172  0.035909  0.000034
# Walking_exhale_8.wav   0.0  0.009344  3.317659  0.002731  0.033188  0.000011
#
#                        6    7          8         9    ...           126  \
# Dyspnea_exhale_3.wav   0.0  0.0 -45.334891  0.490578  ... -6.866427e-11
# Dyspnea_exhale_2.wav   0.0  0.0 -46.882612 -0.084901  ...  1.275051e-08
# Dyspnea_exhale_1.wav   0.0  0.0 -46.813120 -0.120158  ... -5.702810e-11
# Dyspnea_exhale_5.wav   0.0  0.0 -47.010755 -0.054928  ... -3.329055e-11
# Dyspnea_exhale_4.wav   0.0  0.0 -48.923292 -0.788085  ...  2.846411e-10
# ...                    ...  ...        ...       ...  ...           ...
# Walking_exhale_10.wav  0.0  0.0 -46.017261  0.186515  ...  3.020963e-06
# Walking_inhale_9.wav   0.0  0.0 -46.547248  0.684925  ... -1.148940e-10
# Walking_inhale_8.wav   0.0  0.0 -43.101846  1.685298  ...  3.755436e-09
# Walking_exhale_9.wav   0.0  0.0 -45.430178  0.337116  ... -5.669973e-10
# Walking_exhale_8.wav   0.0  0.0 -46.031773  0.983000  ...  6.346895e-06
#
#                                 127           128           129           130  \
# Dyspnea_exhale_3.wav   1.390560e-08  3.490652e-12  6.858661e-10  1.125015e-09
# Dyspnea_exhale_2.wav  -1.102144e-05  1.612212e-08  1.566443e-05  6.884011e-08
# Dyspnea_exhale_1.wav  -3.742263e-08 -1.501705e-11  2.361751e-10  2.869218e-10
# Dyspnea_exhale_5.wav  -1.533664e-08 -2.336839e-11 -3.190830e-10 -2.435295e-10
# Dyspnea_exhale_4.wav  -1.914558e-07  1.725791e-11  8.306831e-10 -1.147676e-09
# ...                             ...           ...           ...           ...
# Walking_exhale_10.wav -2.703819e-05  3.153482e-06  4.461459e-05 -7.424396e-09
# Walking_inhale_9.wav  -5.683385e-08 -1.174590e-10 -2.165971e-09 -3.093970e-10
# Walking_inhale_8.wav  -1.988819e-07 -1.492684e-09  6.078296e-08  7.596586e-09
# Walking_exhale_9.wav   9.515602e-09  3.274330e-10  5.941010e-09  4.434255e-09
# Walking_exhale_8.wav  -7.448934e-05  1.581182e-06  1.118460e-04  7.884763e-09
#
#                                 131           132           133           134  \
# Dyspnea_exhale_3.wav   5.993740e-11  6.627394e-11  8.946676e-11 -4.669298e-11
# Dyspnea_exhale_2.wav   6.282312e-08  7.346283e-07  2.736374e-06  1.169237e-09
# Dyspnea_exhale_1.wav   3.179822e-11  7.285976e-11  8.526325e-11 -7.739882e-11
# Dyspnea_exhale_5.wav  -1.918749e-11  1.722668e-11  5.328989e-12  2.177929e-11
# Dyspnea_exhale_4.wav  -3.202150e-10  1.135248e-10  2.381244e-11 -6.104102e-11
# ...                             ...           ...           ...           ...
# Walking_exhale_10.wav  7.283267e-07  2.797163e-07  1.916602e-06  1.442800e-08
# Walking_inhale_9.wav   1.544577e-11 -7.935396e-11 -4.620005e-11 -6.834915e-11
# Walking_inhale_8.wav   1.855473e-09  8.679270e-09  2.853362e-08  1.984137e-09
# Walking_exhale_9.wav   2.412263e-10  1.516937e-11  4.115886e-11  1.528110e-10
# Walking_exhale_8.wav   8.812973e-07  2.347128e-06  1.055545e-05  1.450501e-06
#
#                                 135
# Dyspnea_exhale_3.wav   3.794662e-09
# Dyspnea_exhale_2.wav  -3.734947e-06
# Dyspnea_exhale_1.wav  -1.036263e-08
# Dyspnea_exhale_5.wav  -4.223393e-09
# Dyspnea_exhale_4.wav  -5.291137e-08
# ...                             ...
# Walking_exhale_10.wav -9.399886e-06
# Walking_inhale_9.wav  -1.558203e-08
# Walking_inhale_8.wav  -6.056441e-08
# Walking_exhale_9.wav   2.354592e-09
# Walking_exhale_8.wav  -2.525167e-05
#
# [120 rows x 136 columns]

# %%
df_clusterize = df.copy()
for dropped_columns in [0, 6, 7]:
    df_clusterize = df_clusterize.drop(dropped_columns, axis=1)

for dropped_columns in range(21, 33):
    df_clusterize = df_clusterize.drop(dropped_columns, axis=1)

# for dropped_columns in range(21 + 68, 33 + 68):
#     df_classification = df_classification.drop(dropped_columns, axis=1)

for dropped_columns in range(34, 136):
    df_clusterize = df_clusterize.drop(dropped_columns, axis=1)

# df_clusterize

df_clusterize['transcript'] = ""

# %%
logs = {}
for activity in activities:
    filename = f'../web_recordings/{activity}/{activity}_transcript_log.txt'
    data = open(filename)
    for line in data:
        transcript_line = line.split(' ')
        transcript_filename = f'{transcript_line[0]}_{transcript_line[1]}_{transcript_line[2][:-1]}.wav'
        # print(transcript_line[3][:-1])
        df_clusterize['transcript'].loc[transcript_filename] = transcript_line[3][:-1]
# Out:
# /var/folders/0q/dmmw0czd77q_7wbcnprrfx2c0000gn/T/ipykernel_17641/2512247548.py:9: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df_clusterize['transcript'].loc[transcript_filename] = transcript_line[3][:-1]
# /var/folders/0q/dmmw0czd77q_7wbcnprrfx2c0000gn/T/ipykernel_17641/2512247548.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_clusterize['transcript'].loc[transcript_filename] = transcript_line[3][:-1]
# /var/folders/0q/dmmw0czd77q_7wbcnprrfx2c0000gn/T/ipykernel_17641/2512247548.py:9: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df_clusterize['transcript'].loc[transcript_filename] = transcript_line[3][:-1]
# /var/folders/0q/dmmw0czd77q_7wbcnprrfx2c0000gn/T/ipykernel_17641/2512247548.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_clusterize['transcript'].loc[transcript_filename] = transcript_line[3][:-1]
# /var/folders/0q/dmmw0czd77q_7wbcnprrfx2c0000gn/T/ipykernel_17641/2512247548.py:9: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df_clusterize['transcript'].loc[transcript_filename] = transcript_line[3][:-1]
# /var/folders/0q/dmmw0czd77q_7wbcnprrfx2c0000gn/T/ipykernel_17641/2512247548.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_clusterize['transcript'].loc[transcript_filename] = transcript_line[3][:-1]
# /var/folders/0q/dmmw0czd77q_7wbcnprrfx2c0000gn/T/ipykernel_17641/2512247548.py:9: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df_clusterize['transcript'].loc[transcript_filename] = transcript_line[3][:-1]
# /var/folders/0q/dmmw0czd77q_7wbcnprrfx2c0000gn/T/ipykernel_17641/2512247548.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_clusterize['transcript'].loc[transcript_filename] = transcript_line[3][:-1]
# /var/folders/0q/dmmw0czd77q_7wbcnprrfx2c0000gn/T/ipykernel_17641/2512247548.py:9: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df_clusterize['transcript'].loc[transcript_filename] = transcript_line[3][:-1]
# /var/folders/0q/dmmw0czd77q_7wbcnprrfx2c0000gn/T/ipykernel_17641/2512247548.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_clusterize['transcript'].loc[transcript_filename] = transcript_line[3][:-1]
# /var/folders/0q/dmmw0czd77q_7wbcnprrfx2c0000gn/T/ipykernel_17641/2512247548.py:9: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df_clusterize['transcript'].loc[transcript_filename] = transcript_line[3][:-1]
# /var/folders/0q/dmmw0czd77q_7wbcnprrfx2c0000gn/T/ipykernel_17641/2512247548.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_clusterize['transcript'].loc[transcript_filename] = transcript_line[3][:-1]
# /var/folders/0q/dmmw0czd77q_7wbcnprrfx2c0000gn/T/ipykernel_17641/2512247548.py:9: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df_clusterize['transcript'].loc[transcript_filename] = transcript_line[3][:-1]
# /var/folders/0q/dmmw0czd77q_7wbcnprrfx2c0000gn/T/ipykernel_17641/2512247548.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_clusterize['transcript'].loc[transcript_filename] = transcript_line[3][:-1]
# /var/folders/0q/dmmw0czd77q_7wbcnprrfx2c0000gn/T/ipykernel_17641/2512247548.py:9: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df_clusterize['transcript'].loc[transcript_filename] = transcript_line[3][:-1]
# /var/folders/0q/dmmw0czd77q_7wbcnprrfx2c0000gn/T/ipykernel_17641/2512247548.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_clusterize['transcript'].loc[transcript_filename] = transcript_line[3][:-1]
# /var/folders/0q/dmmw0czd77q_7wbcnprrfx2c0000gn/T/ipykernel_17641/2512247548.py:9: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df_clusterize['transcript'].loc[transcript_filename] = transcript_line[3][:-1]
# /var/folders/0q/dmmw0czd77q_7wbcnprrfx2c0000gn/T/ipykernel_17641/2512247548.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_clusterize['transcript'].loc[transcript_filename] = transcript_line[3][:-1]
# /var/folders/0q/dmmw0czd77q_7wbcnprrfx2c0000gn/T/ipykernel_17641/2512247548.py:9: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df_clusterize['transcript'].loc[transcript_filename] = transcript_line[3][:-1]
# /var/folders/0q/dmmw0czd77q_7wbcnprrfx2c0000gn/T/ipykernel_17641/2512247548.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_clusterize['transcript'].loc[transcript_filename] = transcript_line[3][:-1]
# /var/folders/0q/dmmw0czd77q_7wbcnprrfx2c0000gn/T/ipykernel_17641/2512247548.py:9: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df_clusterize['transcript'].loc[transcript_filename] = transcript_line[3][:-1]
# /var/folders/0q/dmmw0czd77q_7wbcnprrfx2c0000gn/T/ipykernel_17641/2512247548.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_clusterize['transcript'].loc[transcript_filename] = transcript_line[3][:-1]
# /var/folders/0q/dmmw0czd77q_7wbcnprrfx2c0000gn/T/ipykernel_17641/2512247548.py:9: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df_clusterize['transcript'].loc[transcript_filename] = transcript_line[3][:-1]
# /var/folders/0q/dmmw0czd77q_7wbcnprrfx2c0000gn/T/ipykernel_17641/2512247548.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_clusterize['transcript'].loc[transcript_filename] = transcript_line[3][:-1]
# /var/folders/0q/dmmw0czd77q_7wbcnprrfx2c0000gn/T/ipykernel_17641/2512247548.py:9: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df_clusterize['transcript'].loc[transcript_filename] = transcript_line[3][:-1]
# /var/folders/0q/dmmw0czd77q_7wbcnprrfx2c0000gn/T/ipykernel_17641/2512247548.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_clusterize['transcript'].loc[transcript_filename] = transcript_line[3][:-1]
# /var/folders/0q/dmmw0czd77q_7wbcnprrfx2c0000gn/T/ipykernel_17641/2512247548.py:9: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df_clusterize['transcript'].loc[transcript_filename] = transcript_line[3][:-1]
# /var/folders/0q/dmmw0czd77q_7wbcnprrfx2c0000gn/T/ipykernel_17641/2512247548.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_clusterize['transcript'].loc[transcript_filename] = transcript_line[3][:-1]
# /var/folders/0q/dmmw0czd77q_7wbcnprrfx2c0000gn/T/ipykernel_17641/2512247548.py:9: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df_clusterize['transcript'].loc[transcript_filename] = transcript_line[3][:-1]
# /var/folders/0q/dmmw0czd77q_7wbcnprrfx2c0000gn/T/ipykernel_17641/2512247548.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_clusterize['transcript'].loc[transcript_filename] = transcript_line[3][:-1]
# /var/folders/0q/dmmw0czd77q_7wbcnprrfx2c0000gn/T/ipykernel_17641/2512247548.py:9: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df_clusterize['transcript'].loc[transcript_filename] = transcript_line[3][:-1]
# /var/folders/0q/dmmw0czd77q_7wbcnprrfx2c0000gn/T/ipykernel_17641/2512247548.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_clusterize['transcript'].loc[transcript_filename] = transcript_line[3][:-1]
# /var/folders/0q/dmmw0czd77q_7wbcnprrfx2c0000gn/T/ipykernel_17641/2512247548.py:9: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df_clusterize['transcript'].loc[transcript_filename] = transcript_line[3][:-1]
# /var/folders/0q/dmmw0czd77q_7wbcnprrfx2c0000gn/T/ipykernel_17641/2512247548.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_clusterize['transcript'].loc[transcript_filename] = transcript_line[3][:-1]
# /var/folders/0q/dmmw0czd77q_7wbcnprrfx2c0000gn/T/ipykernel_17641/2512247548.py:9: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df_clusterize['transcript'].loc[transcript_filename] = transcript_line[3][:-1]
# /var/folders/0q/dmmw0czd77q_7wbcnprrfx2c0000gn/T/ipykernel_17641/2512247548.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_clusterize['transcript'].loc[transcript_filename] = transcript_line[3][:-1]
# /var/folders/0q/dmmw0czd77q_7wbcnprrfx2c0000gn/T/ipykernel_17641/2512247548.py:9: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df_clusterize['transcript'].loc[transcript_filename] = transcript_line[3][:-1]
# /var/folders/0q/dmmw0czd77q_7wbcnprrfx2c0000gn/T/ipykernel_17641/2512247548.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_clusterize['transcript'].loc[transcript_filename] = transcript_line[3][:-1]
# /var/folders/0q/dmmw0czd77q_7wbcnprrfx2c0000gn/T/ipykernel_17641/2512247548.py:9: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df_clusterize['transcript'].loc[transcript_filename] = transcript_line[3][:-1]
# /var/folders/0q/dmmw0czd77q_7wbcnprrfx2c0000gn/T/ipykernel_17641/2512247548.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_clusterize['transcript'].loc[transcript_filename] = transcript_line[3][:-1]
# /var/folders/0q/dmmw0czd77q_7wbcnprrfx2c0000gn/T/ipykernel_17641/2512247548.py:9: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df_clusterize['transcript'].loc[transcript_filename] = transcript_line[3][:-1]
# /var/folders/0q/dmmw0czd77q_7wbcnprrfx2c0000gn/T/ipykernel_17641/2512247548.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_clusterize['transcript'].loc[transcript_filename] = transcript_line[3][:-1]
# /var/folders/0q/dmmw0czd77q_7wbcnprrfx2c0000gn/T/ipykernel_17641/2512247548.py:9: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df_clusterize['transcript'].loc[transcript_filename] = transcript_line[3][:-1]
# /var/folders/0q/dmmw0czd77q_7wbcnprrfx2c0000gn/T/ipykernel_17641/2512247548.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_clusterize['transcript'].loc[transcript_filename] = transcript_line[3][:-1]
# /var/folders/0q/dmmw0czd77q_7wbcnprrfx2c0000gn/T/ipykernel_17641/2512247548.py:9: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df_clusterize['transcript'].loc[transcript_filename] = transcript_line[3][:-1]
# /var/folders/0q/dmmw0czd77q_7wbcnprrfx2c0000gn/T/ipykernel_17641/2512247548.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_clusterize['transcript'].loc[transcript_filename] = transcript_line[3][:-1]
# /var/folders/0q/dmmw0czd77q_7wbcnprrfx2c0000gn/T/ipykernel_17641/2512247548.py:9: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df_clusterize['transcript'].loc[transcript_filename] = transcript_line[3][:-1]
# /var/folders/0q/dmmw0czd77q_7wbcnprrfx2c0000gn/T/ipykernel_17641/2512247548.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_clusterize['transcript'].loc[transcript_filename] = transcript_line[3][:-1]
# /var/folders/0q/dmmw0czd77q_7wbcnprrfx2c0000gn/T/ipykernel_17641/2512247548.py:9: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df_clusterize['transcript'].loc[transcript_filename] = transcript_line[3][:-1]
# /var/folders/0q/dmmw0czd77q_7wbcnprrfx2c0000gn/T/ipykernel_17641/2512247548.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_clusterize['transcript'].loc[transcript_filename] = transcript_line[3][:-1]
# /var/folders/0q/dmmw0czd77q_7wbcnprrfx2c0000gn/T/ipykernel_17641/2512247548.py:9: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df_clusterize['transcript'].loc[transcript_filename] = transcript_line[3][:-1]
# /var/folders/0q/dmmw0czd77q_7wbcnprrfx2c0000gn/T/ipykernel_17641/2512247548.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_clusterize['transcript'].loc[transcript_filename] = transcript_line[3][:-1]
# /var/folders/0q/dmmw0czd77q_7wbcnprrfx2c0000gn/T/ipykernel_17641/2512247548.py:9: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df_clusterize['transcript'].loc[transcript_filename] = transcript_line[3][:-1]
# /var/folders/0q/dmmw0czd77q_7wbcnprrfx2c0000gn/T/ipykernel_17641/2512247548.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_clusterize['transcript'].loc[transcript_filename] = transcript_line[3][:-1]
# /var/folders/0q/dmmw0czd77q_7wbcnprrfx2c0000gn/T/ipykernel_17641/2512247548.py:9: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df_clusterize['transcript'].loc[transcript_filename] = transcript_line[3][:-1]
# /var/folders/0q/dmmw0czd77q_7wbcnprrfx2c0000gn/T/ipykernel_17641/2512247548.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_clusterize['transcript'].loc[transcript_filename] = transcript_line[3][:-1]
# /var/folders/0q/dmmw0czd77q_7wbcnprrfx2c0000gn/T/ipykernel_17641/2512247548.py:9: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df_clusterize['transcript'].loc[transcript_filename] = transcript_line[3][:-1]
# /var/folders/0q/dmmw0czd77q_7wbcnprrfx2c0000gn/T/ipykernel_17641/2512247548.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_clusterize['transcript'].loc[transcript_filename] = transcript_line[3][:-1]
# /var/folders/0q/dmmw0czd77q_7wbcnprrfx2c0000gn/T/ipykernel_17641/2512247548.py:9: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df_clusterize['transcript'].loc[transcript_filename] = transcript_line[3][:-1]
# /var/folders/0q/dmmw0czd77q_7wbcnprrfx2c0000gn/T/ipykernel_17641/2512247548.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_clusterize['transcript'].loc[transcript_filename] = transcript_line[3][:-1]
# /var/folders/0q/dmmw0czd77q_7wbcnprrfx2c0000gn/T/ipykernel_17641/2512247548.py:9: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df_clusterize['transcript'].loc[transcript_filename] = transcript_line[3][:-1]
# /var/folders/0q/dmmw0czd77q_7wbcnprrfx2c0000gn/T/ipykernel_17641/2512247548.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_clusterize['transcript'].loc[transcript_filename] = transcript_line[3][:-1]
# /var/folders/0q/dmmw0czd77q_7wbcnprrfx2c0000gn/T/ipykernel_17641/2512247548.py:9: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df_clusterize['transcript'].loc[transcript_filename] = transcript_line[3][:-1]
# /var/folders/0q/dmmw0czd77q_7wbcnprrfx2c0000gn/T/ipykernel_17641/2512247548.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_clusterize['transcript'].loc[transcript_filename] = transcript_line[3][:-1]
# /var/folders/0q/dmmw0czd77q_7wbcnprrfx2c0000gn/T/ipykernel_17641/2512247548.py:9: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df_clusterize['transcript'].loc[transcript_filename] = transcript_line[3][:-1]
# /var/folders/0q/dmmw0czd77q_7wbcnprrfx2c0000gn/T/ipykernel_17641/2512247548.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_clusterize['transcript'].loc[transcript_filename] = transcript_line[3][:-1]
# /var/folders/0q/dmmw0czd77q_7wbcnprrfx2c0000gn/T/ipykernel_17641/2512247548.py:9: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df_clusterize['transcript'].loc[transcript_filename] = transcript_line[3][:-1]
# /var/folders/0q/dmmw0czd77q_7wbcnprrfx2c0000gn/T/ipykernel_17641/2512247548.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_clusterize['transcript'].loc[transcript_filename] = transcript_line[3][:-1]
# /var/folders/0q/dmmw0czd77q_7wbcnprrfx2c0000gn/T/ipykernel_17641/2512247548.py:9: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df_clusterize['transcript'].loc[transcript_filename] = transcript_line[3][:-1]
# /var/folders/0q/dmmw0czd77q_7wbcnprrfx2c0000gn/T/ipykernel_17641/2512247548.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_clusterize['transcript'].loc[transcript_filename] = transcript_line[3][:-1]
# /var/folders/0q/dmmw0czd77q_7wbcnprrfx2c0000gn/T/ipykernel_17641/2512247548.py:9: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# ...
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df_clusterize['transcript'].loc[transcript_filename] = transcript_line[3][:-1]
# /var/folders/0q/dmmw0czd77q_7wbcnprrfx2c0000gn/T/ipykernel_17641/2512247548.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_clusterize['transcript'].loc[transcript_filename] = transcript_line[3][:-1]
# /var/folders/0q/dmmw0czd77q_7wbcnprrfx2c0000gn/T/ipykernel_17641/2512247548.py:9: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df_clusterize['transcript'].loc[transcript_filename] = transcript_line[3][:-1]
# /var/folders/0q/dmmw0czd77q_7wbcnprrfx2c0000gn/T/ipykernel_17641/2512247548.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_clusterize['transcript'].loc[transcript_filename] = transcript_line[3][:-1]
# /var/folders/0q/dmmw0czd77q_7wbcnprrfx2c0000gn/T/ipykernel_17641/2512247548.py:9: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df_clusterize['transcript'].loc[transcript_filename] = transcript_line[3][:-1]
# /var/folders/0q/dmmw0czd77q_7wbcnprrfx2c0000gn/T/ipykernel_17641/2512247548.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_clusterize['transcript'].loc[transcript_filename] = transcript_line[3][:-1]
# /var/folders/0q/dmmw0czd77q_7wbcnprrfx2c0000gn/T/ipykernel_17641/2512247548.py:9: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df_clusterize['transcript'].loc[transcript_filename] = transcript_line[3][:-1]
# /var/folders/0q/dmmw0czd77q_7wbcnprrfx2c0000gn/T/ipykernel_17641/2512247548.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_clusterize['transcript'].loc[transcript_filename] = transcript_line[3][:-1]
# /var/folders/0q/dmmw0czd77q_7wbcnprrfx2c0000gn/T/ipykernel_17641/2512247548.py:9: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df_clusterize['transcript'].loc[transcript_filename] = transcript_line[3][:-1]
# /var/folders/0q/dmmw0czd77q_7wbcnprrfx2c0000gn/T/ipykernel_17641/2512247548.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_clusterize['transcript'].loc[transcript_filename] = transcript_line[3][:-1]
# /var/folders/0q/dmmw0czd77q_7wbcnprrfx2c0000gn/T/ipykernel_17641/2512247548.py:9: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df_clusterize['transcript'].loc[transcript_filename] = transcript_line[3][:-1]
# /var/folders/0q/dmmw0czd77q_7wbcnprrfx2c0000gn/T/ipykernel_17641/2512247548.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_clusterize['transcript'].loc[transcript_filename] = transcript_line[3][:-1]
# /var/folders/0q/dmmw0czd77q_7wbcnprrfx2c0000gn/T/ipykernel_17641/2512247548.py:9: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df_clusterize['transcript'].loc[transcript_filename] = transcript_line[3][:-1]
# /var/folders/0q/dmmw0czd77q_7wbcnprrfx2c0000gn/T/ipykernel_17641/2512247548.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_clusterize['transcript'].loc[transcript_filename] = transcript_line[3][:-1]
# /var/folders/0q/dmmw0czd77q_7wbcnprrfx2c0000gn/T/ipykernel_17641/2512247548.py:9: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df_clusterize['transcript'].loc[transcript_filename] = transcript_line[3][:-1]
# /var/folders/0q/dmmw0czd77q_7wbcnprrfx2c0000gn/T/ipykernel_17641/2512247548.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_clusterize['transcript'].loc[transcript_filename] = transcript_line[3][:-1]
# /var/folders/0q/dmmw0czd77q_7wbcnprrfx2c0000gn/T/ipykernel_17641/2512247548.py:9: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df_clusterize['transcript'].loc[transcript_filename] = transcript_line[3][:-1]
# /var/folders/0q/dmmw0czd77q_7wbcnprrfx2c0000gn/T/ipykernel_17641/2512247548.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_clusterize['transcript'].loc[transcript_filename] = transcript_line[3][:-1]
# /var/folders/0q/dmmw0czd77q_7wbcnprrfx2c0000gn/T/ipykernel_17641/2512247548.py:9: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df_clusterize['transcript'].loc[transcript_filename] = transcript_line[3][:-1]
# /var/folders/0q/dmmw0czd77q_7wbcnprrfx2c0000gn/T/ipykernel_17641/2512247548.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_clusterize['transcript'].loc[transcript_filename] = transcript_line[3][:-1]
# /var/folders/0q/dmmw0czd77q_7wbcnprrfx2c0000gn/T/ipykernel_17641/2512247548.py:9: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df_clusterize['transcript'].loc[transcript_filename] = transcript_line[3][:-1]
# /var/folders/0q/dmmw0czd77q_7wbcnprrfx2c0000gn/T/ipykernel_17641/2512247548.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_clusterize['transcript'].loc[transcript_filename] = transcript_line[3][:-1]
# /var/folders/0q/dmmw0czd77q_7wbcnprrfx2c0000gn/T/ipykernel_17641/2512247548.py:9: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df_clusterize['transcript'].loc[transcript_filename] = transcript_line[3][:-1]
# /var/folders/0q/dmmw0czd77q_7wbcnprrfx2c0000gn/T/ipykernel_17641/2512247548.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_clusterize['transcript'].loc[transcript_filename] = transcript_line[3][:-1]

# %%
df_clusterize
# Out:
#                               1         2         3         4         5  \
# Dyspnea_exhale_3.wav   0.012806  3.317673  0.002670  0.029585  0.000113
# Dyspnea_exhale_2.wav   0.000804  3.317594  0.007379  0.062256  0.000188
# Dyspnea_exhale_1.wav   0.010515  3.317643  0.002303  0.028619  0.000002
# Dyspnea_exhale_5.wav   0.012740  3.317729  0.002582  0.029792  0.000094
# Dyspnea_exhale_4.wav   0.000469  3.317633  0.006905  0.056993  0.001146
# ...                         ...       ...       ...       ...       ...
# Walking_exhale_10.wav  0.002698  3.317677  0.003698  0.039918  0.000023
# Walking_inhale_9.wav   0.008702  3.317718  0.002517  0.030538  0.000007
# Walking_inhale_8.wav   0.011694  3.317635  0.002565  0.029961  0.000010
# Walking_exhale_9.wav   0.006850  3.317664  0.003172  0.035909  0.000034
# Walking_exhale_8.wav   0.009344  3.317659  0.002731  0.033188  0.000011
#
#                                8         9        10        11        12  \
# Dyspnea_exhale_3.wav  -45.334891  0.490578 -1.832355 -1.054599  1.278921
# Dyspnea_exhale_2.wav  -46.882612 -0.084901 -1.458478 -1.207348  0.871057
# Dyspnea_exhale_1.wav  -46.813120 -0.120158 -2.209376 -0.860556  1.260459
# Dyspnea_exhale_5.wav  -47.010755 -0.054928 -1.432415 -1.125739  1.349913
# Dyspnea_exhale_4.wav  -48.923292 -0.788085 -1.497788 -0.691126  1.498575
# ...                          ...       ...       ...       ...       ...
# Walking_exhale_10.wav -46.017261  0.186515 -2.056355 -1.170519  1.051926
# Walking_inhale_9.wav  -46.547248  0.684925 -1.229023 -0.283696  1.018980
# Walking_inhale_8.wav  -43.101846  1.685298 -1.252784 -0.589215  0.707981
# Walking_exhale_9.wav  -45.430178  0.337116 -1.715689 -1.243755  0.807236
# Walking_exhale_8.wav  -46.031773  0.983000 -0.330263  0.195198  1.126835
#
#                              13        14        15        16        17  \
# Dyspnea_exhale_3.wav   0.150162 -0.494087  0.757571 -0.928969  0.152278
# Dyspnea_exhale_2.wav   0.167427 -0.354102  0.632070 -0.892782  0.172083
# Dyspnea_exhale_1.wav  -0.182079 -0.293283  0.283785 -0.577972 -0.182297
# Dyspnea_exhale_5.wav   0.250898 -0.540844  0.771387 -0.715710  0.600385
# Dyspnea_exhale_4.wav  -0.004970 -1.031787  0.462356 -0.861208  0.154169
# ...                         ...       ...       ...       ...       ...
# Walking_exhale_10.wav  0.230227 -0.392596  0.314208 -0.438443  0.291220
# Walking_inhale_9.wav  -0.341183  0.121417  1.037860 -0.634573 -0.166995
# Walking_inhale_8.wav   0.639632 -0.273160  0.345471 -0.703134  0.105194
# Walking_exhale_9.wav   0.448597 -0.203917  0.411391 -0.769462  0.155357
# Walking_exhale_8.wav   0.334515  0.276938  0.642930 -0.554111 -0.088323
#
#                              18        19        20        33  \
# Dyspnea_exhale_3.wav  -0.180459  0.947806 -0.989287  0.046064
# Dyspnea_exhale_2.wav  -0.113934  0.632333 -0.737913  0.046063
# Dyspnea_exhale_1.wav   0.079415  0.546806 -0.700873  0.046064
# Dyspnea_exhale_5.wav  -0.102779  1.103075 -0.892812  0.046064
# Dyspnea_exhale_4.wav  -0.440761  1.232708 -1.158310  0.046059
# ...                         ...       ...       ...       ...
# Walking_exhale_10.wav -0.029049  0.770478 -0.469380  0.046064
# Walking_inhale_9.wav  -0.066688  0.899792 -0.708631  0.046064
# Walking_inhale_8.wav   0.233209  0.748748 -0.685037  0.046064
# Walking_exhale_9.wav   0.138954  0.952452 -0.682581  0.046064
# Walking_exhale_8.wav  -0.508783  0.896792 -0.208194  0.046064
#
#                                transcript
# Dyspnea_exhale_3.wav          щщффтфффффч
# Dyspnea_exhale_2.wav          фттфтттфтфф
# Dyspnea_exhale_1.wav         ффффтфтфффшщ
# Dyspnea_exhale_5.wav         щщщфитфффффщ
# Dyspnea_exhale_4.wav         щщчффффттффч
# ...                                   ...
# Walking_exhale_10.wav      фффтфттффффффщ
# Walking_inhale_9.wav    фффффтттфффффтффщ
# Walking_inhale_8.wav        фщттттфтттффф
# Walking_exhale_9.wav     фффффттттффффтфщ
# Walking_exhale_8.wav   тффффттттффтфщщщщч
#
# [120 rows x 20 columns]

# %%
from scipy.cluster.hierarchy import ward, dendrogram, leaves_list
from scipy.spatial.distance import pdist

df_ward = df_clusterize.transpose()
df_ward.fillna(0, inplace=True)
feature_matrix = df_ward.T.values # n dimensional, m observations.
Z = ward(pdist(feature_matrix))
ll = list(leaves_list(Z))
breathe_moment = df_ward.columns[ll]
list_of_dir_wavs = [x for x in df_ward.columns]
dn = dendrogram(Z, labels = list_of_dir_wavs, orientation = 'left')
plt.savefig('dendrogram_ward_transcript.png')
plt.close()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[12], line 7
#       5 df_ward.fillna(0, inplace=True)
#       6 feature_matrix = df_ward.T.values # n dimensional, m observations.
# ----> 7 Z = ward(pdist(feature_matrix))
#       8 ll = list(leaves_list(Z))
#       9 breathe_moment = df_ward.columns[ll]
#
# File ~/project/breathing_analysis/.venv/lib/python3.11/site-packages/scipy/spatial/distance.py:2322, in pdist(X, metric, out, **kwargs)
#    2320 if metric_info is not None:
#    2321     pdist_fn = metric_info.pdist_func
# -> 2322     return pdist_fn(X, out=out, **kwargs)
#    2323 elif mstr.startswith("test_"):
#    2324     metric_info = _TEST_METRICS.get(mstr, None)
#
# ValueError: Unsupported dtype object

# %%
from sklearn.feature_extraction.text import HashingVectorizer
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans
from scipy.sparse import hstack

vectorizer = TfidfVectorizer(analyzer='char_wb', ngram_range=(3, 5))
tfidf_features = vectorizer.fit_transform(df_clusterize['transcript'])

combined_features = hstack([tfidf_features])

kmeans = KMeans(n_clusters=2, random_state=42)
clusters = kmeans.fit_predict(combined_features)
df_clusterize['cluster'] = clusters

df_clusterize
# Out:
#                               1         2         3         4         5  \
# Dyspnea_exhale_3.wav   0.012806  3.317673  0.002670  0.029585  0.000113
# Dyspnea_exhale_2.wav   0.000804  3.317594  0.007379  0.062256  0.000188
# Dyspnea_exhale_1.wav   0.010515  3.317643  0.002303  0.028619  0.000002
# Dyspnea_exhale_5.wav   0.012740  3.317729  0.002582  0.029792  0.000094
# Dyspnea_exhale_4.wav   0.000469  3.317633  0.006905  0.056993  0.001146
# ...                         ...       ...       ...       ...       ...
# Walking_exhale_10.wav  0.002698  3.317677  0.003698  0.039918  0.000023
# Walking_inhale_9.wav   0.008702  3.317718  0.002517  0.030538  0.000007
# Walking_inhale_8.wav   0.011694  3.317635  0.002565  0.029961  0.000010
# Walking_exhale_9.wav   0.006850  3.317664  0.003172  0.035909  0.000034
# Walking_exhale_8.wav   0.009344  3.317659  0.002731  0.033188  0.000011
#
#                                8         9        10        11        12  ...  \
# Dyspnea_exhale_3.wav  -45.334891  0.490578 -1.832355 -1.054599  1.278921  ...
# Dyspnea_exhale_2.wav  -46.882612 -0.084901 -1.458478 -1.207348  0.871057  ...
# Dyspnea_exhale_1.wav  -46.813120 -0.120158 -2.209376 -0.860556  1.260459  ...
# Dyspnea_exhale_5.wav  -47.010755 -0.054928 -1.432415 -1.125739  1.349913  ...
# Dyspnea_exhale_4.wav  -48.923292 -0.788085 -1.497788 -0.691126  1.498575  ...
# ...                          ...       ...       ...       ...       ...  ...
# Walking_exhale_10.wav -46.017261  0.186515 -2.056355 -1.170519  1.051926  ...
# Walking_inhale_9.wav  -46.547248  0.684925 -1.229023 -0.283696  1.018980  ...
# Walking_inhale_8.wav  -43.101846  1.685298 -1.252784 -0.589215  0.707981  ...
# Walking_exhale_9.wav  -45.430178  0.337116 -1.715689 -1.243755  0.807236  ...
# Walking_exhale_8.wav  -46.031773  0.983000 -0.330263  0.195198  1.126835  ...
#
#                              14        15        16        17        18  \
# Dyspnea_exhale_3.wav  -0.494087  0.757571 -0.928969  0.152278 -0.180459
# Dyspnea_exhale_2.wav  -0.354102  0.632070 -0.892782  0.172083 -0.113934
# Dyspnea_exhale_1.wav  -0.293283  0.283785 -0.577972 -0.182297  0.079415
# Dyspnea_exhale_5.wav  -0.540844  0.771387 -0.715710  0.600385 -0.102779
# Dyspnea_exhale_4.wav  -1.031787  0.462356 -0.861208  0.154169 -0.440761
# ...                         ...       ...       ...       ...       ...
# Walking_exhale_10.wav -0.392596  0.314208 -0.438443  0.291220 -0.029049
# Walking_inhale_9.wav   0.121417  1.037860 -0.634573 -0.166995 -0.066688
# Walking_inhale_8.wav  -0.273160  0.345471 -0.703134  0.105194  0.233209
# Walking_exhale_9.wav  -0.203917  0.411391 -0.769462  0.155357  0.138954
# Walking_exhale_8.wav   0.276938  0.642930 -0.554111 -0.088323 -0.508783
#
#                              19        20        33          transcript  \
# Dyspnea_exhale_3.wav   0.947806 -0.989287  0.046064         щщффтфффффч
# Dyspnea_exhale_2.wav   0.632333 -0.737913  0.046063         фттфтттфтфф
# Dyspnea_exhale_1.wav   0.546806 -0.700873  0.046064        ффффтфтфффшщ
# Dyspnea_exhale_5.wav   1.103075 -0.892812  0.046064        щщщфитфффффщ
# Dyspnea_exhale_4.wav   1.232708 -1.158310  0.046059        щщчффффттффч
# ...                         ...       ...       ...                 ...
# Walking_exhale_10.wav  0.770478 -0.469380  0.046064      фффтфттффффффщ
# Walking_inhale_9.wav   0.899792 -0.708631  0.046064   фффффтттфффффтффщ
# Walking_inhale_8.wav   0.748748 -0.685037  0.046064       фщттттфтттффф
# Walking_exhale_9.wav   0.952452 -0.682581  0.046064    фффффттттффффтфщ
# Walking_exhale_8.wav   0.896792 -0.208194  0.046064  тффффттттффтфщщщщч
#
#                       cluster
# Dyspnea_exhale_3.wav        1
# Dyspnea_exhale_2.wav        0
# Dyspnea_exhale_1.wav        1
# Dyspnea_exhale_5.wav        1
# Dyspnea_exhale_4.wav        0
# ...                       ...
# Walking_exhale_10.wav       1
# Walking_inhale_9.wav        1
# Walking_inhale_8.wav        0
# Walking_exhale_9.wav        1
# Walking_exhale_8.wav        0
#
# [120 rows x 21 columns]

# %%
hash_vectorizer = HashingVectorizer(analyzer='char_wb', ngram_range=(3, 5), n_features=50)
hashed_features = hash_vectorizer.fit_transform(df_clusterize['transcript'])

combined_features_hash = hstack([hashed_features]) # 

kmeans_hash = KMeans(n_clusters=2, random_state=42)
clusters_hash = kmeans_hash.fit_predict(combined_features_hash)
df_clusterize['cluster_hash'] = clusters_hash

df_clusterize
# Out:
#                               1         2         3         4         5  \
# Dyspnea_exhale_3.wav   0.012806  3.317673  0.002670  0.029585  0.000113
# Dyspnea_exhale_2.wav   0.000804  3.317594  0.007379  0.062256  0.000188
# Dyspnea_exhale_1.wav   0.010515  3.317643  0.002303  0.028619  0.000002
# Dyspnea_exhale_5.wav   0.012740  3.317729  0.002582  0.029792  0.000094
# Dyspnea_exhale_4.wav   0.000469  3.317633  0.006905  0.056993  0.001146
# ...                         ...       ...       ...       ...       ...
# Walking_exhale_10.wav  0.002698  3.317677  0.003698  0.039918  0.000023
# Walking_inhale_9.wav   0.008702  3.317718  0.002517  0.030538  0.000007
# Walking_inhale_8.wav   0.011694  3.317635  0.002565  0.029961  0.000010
# Walking_exhale_9.wav   0.006850  3.317664  0.003172  0.035909  0.000034
# Walking_exhale_8.wav   0.009344  3.317659  0.002731  0.033188  0.000011
#
#                                8         9        10        11        12  ...  \
# Dyspnea_exhale_3.wav  -45.334891  0.490578 -1.832355 -1.054599  1.278921  ...
# Dyspnea_exhale_2.wav  -46.882612 -0.084901 -1.458478 -1.207348  0.871057  ...
# Dyspnea_exhale_1.wav  -46.813120 -0.120158 -2.209376 -0.860556  1.260459  ...
# Dyspnea_exhale_5.wav  -47.010755 -0.054928 -1.432415 -1.125739  1.349913  ...
# Dyspnea_exhale_4.wav  -48.923292 -0.788085 -1.497788 -0.691126  1.498575  ...
# ...                          ...       ...       ...       ...       ...  ...
# Walking_exhale_10.wav -46.017261  0.186515 -2.056355 -1.170519  1.051926  ...
# Walking_inhale_9.wav  -46.547248  0.684925 -1.229023 -0.283696  1.018980  ...
# Walking_inhale_8.wav  -43.101846  1.685298 -1.252784 -0.589215  0.707981  ...
# Walking_exhale_9.wav  -45.430178  0.337116 -1.715689 -1.243755  0.807236  ...
# Walking_exhale_8.wav  -46.031773  0.983000 -0.330263  0.195198  1.126835  ...
#
#                              15        16        17        18        19  \
# Dyspnea_exhale_3.wav   0.757571 -0.928969  0.152278 -0.180459  0.947806
# Dyspnea_exhale_2.wav   0.632070 -0.892782  0.172083 -0.113934  0.632333
# Dyspnea_exhale_1.wav   0.283785 -0.577972 -0.182297  0.079415  0.546806
# Dyspnea_exhale_5.wav   0.771387 -0.715710  0.600385 -0.102779  1.103075
# Dyspnea_exhale_4.wav   0.462356 -0.861208  0.154169 -0.440761  1.232708
# ...                         ...       ...       ...       ...       ...
# Walking_exhale_10.wav  0.314208 -0.438443  0.291220 -0.029049  0.770478
# Walking_inhale_9.wav   1.037860 -0.634573 -0.166995 -0.066688  0.899792
# Walking_inhale_8.wav   0.345471 -0.703134  0.105194  0.233209  0.748748
# Walking_exhale_9.wav   0.411391 -0.769462  0.155357  0.138954  0.952452
# Walking_exhale_8.wav   0.642930 -0.554111 -0.088323 -0.508783  0.896792
#
#                              20        33          transcript  cluster  \
# Dyspnea_exhale_3.wav  -0.989287  0.046064         щщффтфффффч        1
# Dyspnea_exhale_2.wav  -0.737913  0.046063         фттфтттфтфф        0
# Dyspnea_exhale_1.wav  -0.700873  0.046064        ффффтфтфффшщ        1
# Dyspnea_exhale_5.wav  -0.892812  0.046064        щщщфитфффффщ        1
# Dyspnea_exhale_4.wav  -1.158310  0.046059        щщчффффттффч        0
# ...                         ...       ...                 ...      ...
# Walking_exhale_10.wav -0.469380  0.046064      фффтфттффффффщ        1
# Walking_inhale_9.wav  -0.708631  0.046064   фффффтттфффффтффщ        1
# Walking_inhale_8.wav  -0.685037  0.046064       фщттттфтттффф        0
# Walking_exhale_9.wav  -0.682581  0.046064    фффффттттффффтфщ        1
# Walking_exhale_8.wav  -0.208194  0.046064  тффффттттффтфщщщщч        0
#
#                       cluster_hash
# Dyspnea_exhale_3.wav             1
# Dyspnea_exhale_2.wav             0
# Dyspnea_exhale_1.wav             1
# Dyspnea_exhale_5.wav             1
# Dyspnea_exhale_4.wav             1
# ...                            ...
# Walking_exhale_10.wav            1
# Walking_inhale_9.wav             1
# Walking_inhale_8.wav             0
# Walking_exhale_9.wav             1
# Walking_exhale_8.wav             0
#
# [120 rows x 22 columns]

# %%
df_clusterize[['cluster', 'cluster_hash']].to_csv("df_clusterize.csv")

# %%
import joblib

joblib.dump(kmeans_hash, "model_transcript_breath.pkl")
# Out:
# ['model_transcript_breath.pkl']
